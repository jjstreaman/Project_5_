# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2014_stats_df = pd.read_csv('all_2014_stats_df.csv', index_col=0)

# %%
all_2014_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x', 
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2014_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2014-09-27           93.7          -1.62           6.28
# 1         FF  2014-09-27           93.1          -1.63           6.18
# 2         CU  2014-09-27           77.2          -1.53           6.58
# 3         SL  2014-09-27           87.1          -1.61           6.38
# 4         FF  2014-09-27           92.3          -1.57           6.10
#
#        player_name  pitcher  spin_dir p_throws  game_year  ...       vz0  \
# 0  Hawkins, LaTroy   115629       NaN        R       2014  ... -5.842926
# 1  Hawkins, LaTroy   115629       NaN        R       2014  ... -4.770105
# 2  Hawkins, LaTroy   115629       NaN        R       2014  ... -3.401167
# 3  Hawkins, LaTroy   115629       NaN        R       2014  ... -5.880221
# 4  Hawkins, LaTroy   115629       NaN        R       2014  ... -6.330797
#
#        ax      ay      az  effective_speed  release_spin_rate  \
# 0 -14.522  33.125 -13.576              NaN                NaN
# 1 -16.061  30.346 -18.959              NaN                NaN
# 2   2.464  21.609 -37.445              NaN                NaN
# 3  -1.869  24.236 -20.821              NaN                NaN
# 4 -15.178  29.835 -20.970              NaN                NaN
#
#    release_extension  release_pos_y       pitch_name  spin_axis
# 0                NaN           54.5  4-Seam Fastball        NaN
# 1                NaN           54.5  4-Seam Fastball        NaN
# 2                NaN           54.5        Curveball        NaN
# 3                NaN           54.5           Slider        NaN
# 4                NaN           54.5  4-Seam Fastball        NaN
#
# [5 rows x 22 columns]

# %%
all_2014_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 459914 entries, 0 to 459913
# Data columns (total 17 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pitch_type     452900 non-null  object
#  1   game_date      459914 non-null  object
#  2   release_speed  452900 non-null  float64
#  3   release_pos_x  452899 non-null  float64
#  4   release_pos_z  452899 non-null  float64
#  5   player_name    459914 non-null  object
#  6   pitcher        459914 non-null  int64
#  7   p_throws       459914 non-null  object
#  8   game_year      459914 non-null  int64
#  9   vx0            452899 non-null  float64
#  10  vy0            452899 non-null  float64
#  11  vz0            452899 non-null  float64
#  12  ax             452900 non-null  float64
#  13  ay             452900 non-null  float64
#  14  az             452900 non-null  float64
#  15  release_pos_y  452899 non-null  float64
#  16  pitch_name     452900 non-null  object
# dtypes: float64(10), int64(2), object(5)
# memory usage: 63.2+ MB

# %% [markdown]
# NOTE: More null columns here:
#
# 'spin_dir', 'effective_speed', 'release_spin_rate', 'release_extension', 'spin_axis'

# %%
all_2014_stats_df.drop(columns=['spin_dir', 'spin_axis', 'effective_speed',
                               'release_spin_rate', 'release_extension'], inplace=True)
all_2014_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2014-09-27           93.7          -1.62           6.28
# 1         FF  2014-09-27           93.1          -1.63           6.18
# 2         CU  2014-09-27           77.2          -1.53           6.58
# 3         SL  2014-09-27           87.1          -1.61           6.38
# 4         FF  2014-09-27           92.3          -1.57           6.10
#
#        player_name  pitcher p_throws  game_year       vx0         vy0  \
# 0  Hawkins, LaTroy   115629        R       2014  7.404227 -137.193847
# 1  Hawkins, LaTroy   115629        R       2014  6.773917 -136.378016
# 2  Hawkins, LaTroy   115629        R       2014  5.941635 -113.154648
# 3  Hawkins, LaTroy   115629        R       2014  6.754227 -127.424787
# 4  Hawkins, LaTroy   115629        R       2014  7.210528 -135.074635
#
#         vz0      ax      ay      az  release_pos_y       pitch_name
# 0 -5.842926 -14.522  33.125 -13.576           54.5  4-Seam Fastball
# 1 -4.770105 -16.061  30.346 -18.959           54.5  4-Seam Fastball
# 2 -3.401167   2.464  21.609 -37.445           54.5        Curveball
# 3 -5.880221  -1.869  24.236 -20.821           54.5           Slider
# 4 -6.330797 -15.178  29.835 -20.970           54.5  4-Seam Fastball

# %%
all_2014_stats_df = all_2014_stats_df.dropna(axis=0)

# %%
all_2014_stats_df.reset_index(inplace=True)

# %%
all_2014_stats_df.drop('index', axis=1)
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0              FF  2014-09-27           93.7          -1.62           6.28
# 1              FF  2014-09-27           93.1          -1.63           6.18
# 2              CU  2014-09-27           77.2          -1.53           6.58
# 3              SL  2014-09-27           87.1          -1.61           6.38
# 4              FF  2014-09-27           92.3          -1.57           6.10
# ...           ...         ...            ...            ...            ...
# 452894         CH  2014-04-01           83.3           1.16           5.81
# 452895         SI  2014-04-01           91.5           0.89           5.88
# 452896         CH  2014-04-01           83.4           1.12           5.83
# 452897         SI  2014-04-01           92.0           1.03           5.83
# 452898         SI  2014-04-01           90.7           1.03           5.83
#
#             player_name  pitcher p_throws  game_year       vx0         vy0  \
# 0       Hawkins, LaTroy   115629        R       2014  7.404227 -137.193847
# 1       Hawkins, LaTroy   115629        R       2014  6.773917 -136.378016
# 2       Hawkins, LaTroy   115629        R       2014  5.941635 -113.154648
# 3       Hawkins, LaTroy   115629        R       2014  6.754227 -127.424787
# 4       Hawkins, LaTroy   115629        R       2014  7.210528 -135.074635
# ...                 ...      ...      ...        ...       ...         ...
# 452894       Wood, Alex   622072        L       2014 -5.166140 -122.209151
# 452895       Wood, Alex   622072        L       2014 -6.069854 -134.213583
# 452896       Wood, Alex   622072        L       2014 -3.871874 -122.273176
# 452897       Wood, Alex   622072        L       2014 -4.834544 -134.966424
# 452898       Wood, Alex   622072        L       2014 -4.938186 -133.018954
#
#              vz0      ax      ay      az  release_pos_y       pitch_name
# 0      -5.842926 -14.522  33.125 -13.576           54.5  4-Seam Fastball
# 1      -4.770105 -16.061  30.346 -18.959           54.5  4-Seam Fastball
# 2      -3.401167   2.464  21.609 -37.445           54.5        Curveball
# 3      -5.880221  -1.869  24.236 -20.821           54.5           Slider
# 4      -6.330797 -15.178  29.835 -20.970           54.5  4-Seam Fastball
# ...          ...     ...     ...     ...            ...              ...
# 452894  1.599812  14.963  25.946 -31.861           54.5         Changeup
# 452895 -0.361772  14.287  30.353 -19.052           54.5           Sinker
# 452896 -1.510674  15.885  25.502 -25.479           54.5         Changeup
# 452897 -2.728419  13.850  30.668 -21.500           54.5           Sinker
# 452898 -3.494282  16.175  28.391 -23.436           54.5           Sinker
#
# [452899 rows x 17 columns]

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2014_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2014_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2014_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'release_pos_y': 'mean',
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2014_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2014_df = grouped_2014_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2014_df
# Out:
#         game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0      2014-03-22   450306             96         CH                   30
# 1      2014-03-22   450306             96         CU                   14
# 2      2014-03-22   450306             96         FC                    5
# 3      2014-03-22   450306             96         FF                   46
# 4      2014-03-22   450306             96         SI                    1
# ...           ...      ...            ...        ...                  ...
# 27564  2014-09-28   605135             97         FF                    1
# 27565  2014-09-28   605135             97         SI                   43
# 27566  2014-09-28   605135             97         SL                   23
# 27567  2014-09-28   608665             10         SI                    9
# 27568  2014-09-28   608665             10         SL                    1
#
#        release_speed  release_pos_x  release_pos_z        vx0         vy0  \
# 0          80.300000       1.842667       6.336000  -5.428231 -117.421364
# 1          74.864286       1.832143       6.412857  -3.565039 -109.682758
# 2          85.360000       1.872000       6.222000  -6.749682 -124.716654
# 3          87.436957       1.929348       6.165652  -6.433253 -127.912487
# 4          87.200000       2.100000       6.130000  -7.689498 -127.799401
# ...              ...            ...            ...        ...         ...
# 27564      95.700000      -2.710000       5.700000  11.121121 -139.690142
# 27565      92.818605      -2.723488       5.598372  10.195226 -135.818953
# 27566      84.878261      -2.866957       5.621304   6.650068 -124.266909
# 27567      93.966667      -0.992222       5.527778   5.201414 -137.721602
# 27568      84.100000      -0.760000       5.490000   0.946358 -123.320075
#
#             vz0         ax         ay         az  release_pos_y
# 0     -4.909296  11.868167  20.097500 -20.812833           54.5
# 1     -0.019027  -2.501643  17.359857 -37.129857           54.5
# 2     -5.937519   4.823000  21.606200 -15.057400           54.5
# 3     -5.130557   8.367152  23.855152 -14.967130           54.5
# 4     -1.543986  13.992000  26.609000 -17.685000           54.5
# ...         ...        ...        ...        ...            ...
# 27564 -6.672633 -11.233000  29.980000 -17.675000           54.5
# 27565 -2.545814 -17.496000  30.447023 -22.954000           54.5
# 27566 -0.695274   2.209261  24.399174 -29.316522           54.5
# 27567 -2.799373 -16.659333  31.611111 -24.733778           54.5
# 27568 -0.200798   8.728000  24.304000 -33.291000           54.5
#
# [27569 rows x 15 columns]

# %%
grouped_2014_df['game_date'] = pd.to_datetime(grouped_2014_df['game_date'])
grouped_2014_df['season'] = grouped_2014_df['game_date'].dt.year

# Step 1: Season Total Pitches
season_total_pitches = grouped_2014_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2014_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'release_pos_y']
for col in weighted_avg_columns:
    grouped_2014_df[f'{col}_product'] = grouped_2014_df[col] * grouped_2014_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2014_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2014_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2014_df = pd.merge(final_2014_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2014_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   112526    2014                 12322         CH
# 1   112526    2014                 12322         FF
# 2   112526    2014                 12322         IN
# 3   112526    2014                 12322         SI
# 4   112526    2014                 12322         SL
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                               169                  169
# 1                               856                  856
# 2                                12                   12
# 3                              1604                 1604
# 4                               368                  368
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   81.982249                   -1.368047
# 1                   91.296612                   -0.983995
# 2                   77.458333                   -1.578333
# 3                   88.284663                   -1.360436
# 4                   82.933424                   -1.492880
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.746213          4.308327       -120.124693
# 1                    5.965993          3.258273       -133.873215
# 2                    6.704167          1.327522       -113.545854
# 3                    5.729395          6.062267       -129.407230
# 4                    5.816060          2.996842       -121.513007
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -3.071392       -10.751509        24.318225       -24.679645
# 1         -4.778564        -7.696817        30.512959       -16.409695
# 2          1.362851        -4.324000        22.426583       -23.358083
# 3         -2.437539       -14.784560        28.458998       -24.712448
# 4         -1.778457         2.501505        23.276842       -30.190533
#
#    release_pos_y_weighted_avg
# 0                        54.5
# 1                        54.5
# 2                        54.5
# 3                        54.5
# 4                        54.5

# %%
final_2014_df.to_csv('final_2014_df.csv')
