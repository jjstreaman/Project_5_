# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2020_stats_df = pd.read_csv('all_2020_stats_df.csv', index_col=0)

# %%
all_2020_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x',
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2020_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2020-09-27           88.9           2.98           5.29
# 1         SL  2020-09-27           74.8           2.10           5.73
# 2         SL  2020-09-27           75.3           2.01           5.74
# 3         SL  2020-09-27           75.8           2.38           5.20
# 4         SL  2020-09-27           75.0           2.70           5.15
#
#      player_name  pitcher  spin_dir p_throws  game_year  ...       vz0  \
# 0  Pérez, Oliver   424144       NaN        L       2020  ... -0.989660
# 1  Pérez, Oliver   424144       NaN        L       2020  ...  0.610107
# 2  Pérez, Oliver   424144       NaN        L       2020  ... -2.514557
# 3  Pérez, Oliver   424144       NaN        L       2020  ...  0.343225
# 4  Pérez, Oliver   424144       NaN        L       2020  ...  0.249817
#
#           ax         ay         az  effective_speed  release_spin_rate  \
# 0  20.383213  23.814852 -26.805910             88.9             2130.0
# 1  -4.717873  18.807153 -34.566989             74.8             2069.0
# 2  -6.942147  18.406492 -34.069642             75.4             2244.0
# 3  -3.627673  18.464630 -32.767026             75.7             2252.0
# 4  -2.756490  18.526994 -33.136746             75.2             2113.0
#
#    release_extension  release_pos_y  pitch_name  spin_axis
# 0                6.2          54.34      Sinker      125.0
# 1                6.2          54.28      Slider      309.0
# 2                6.2          54.35      Slider      312.0
# 3                6.1          54.38      Slider      299.0
# 4                6.3          54.16      Slider      293.0
#
# [5 rows x 22 columns]

# %%
all_2020_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131193 entries, 0 to 131192
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         131175 non-null  object
#  1   game_date          131193 non-null  object
#  2   release_speed      131175 non-null  float64
#  3   release_pos_x      131175 non-null  float64
#  4   release_pos_z      131175 non-null  float64
#  5   player_name        131193 non-null  object
#  6   pitcher            131193 non-null  int64
#  7   spin_dir           0 non-null       float64
#  8   p_throws           131193 non-null  object
#  9   game_year          131193 non-null  int64
#  10  vx0                131175 non-null  float64
#  11  vy0                131175 non-null  float64
#  12  vz0                131175 non-null  float64
#  13  ax                 131175 non-null  float64
#  14  ay                 131175 non-null  float64
#  15  az                 131175 non-null  float64
#  16  effective_speed    131188 non-null  float64
#  17  release_spin_rate  130638 non-null  float64
#  18  release_extension  130918 non-null  float64
#  19  release_pos_y      131175 non-null  float64
#  20  pitch_name         131175 non-null  object
#  21  spin_axis          130638 non-null  float64
# dtypes: float64(15), int64(2), object(5)
# memory usage: 23.0+ MB

# %%
all_2020_stats_df = all_2020_stats_df.drop(columns='spin_dir', axis=0)

# %%
all_2020_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131193 entries, 0 to 131192
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         131175 non-null  object
#  1   game_date          131193 non-null  object
#  2   release_speed      131175 non-null  float64
#  3   release_pos_x      131175 non-null  float64
#  4   release_pos_z      131175 non-null  float64
#  5   player_name        131193 non-null  object
#  6   pitcher            131193 non-null  int64
#  7   p_throws           131193 non-null  object
#  8   game_year          131193 non-null  int64
#  9   vx0                131175 non-null  float64
#  10  vy0                131175 non-null  float64
#  11  vz0                131175 non-null  float64
#  12  ax                 131175 non-null  float64
#  13  ay                 131175 non-null  float64
#  14  az                 131175 non-null  float64
#  15  effective_speed    131188 non-null  float64
#  16  release_spin_rate  130638 non-null  float64
#  17  release_extension  130918 non-null  float64
#  18  release_pos_y      131175 non-null  float64
#  19  pitch_name         131175 non-null  object
#  20  spin_axis          130638 non-null  float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 22.0+ MB

# %%
all_2020_stats_df = all_2020_stats_df.dropna(axis=0)

# %%
all_2020_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130573 entries, 0 to 130572
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              130573 non-null  int64
#  1   pitch_type         130573 non-null  object
#  2   game_date          130573 non-null  object
#  3   release_speed      130573 non-null  float64
#  4   release_pos_x      130573 non-null  float64
#  5   release_pos_z      130573 non-null  float64
#  6   player_name        130573 non-null  object
#  7   pitcher            130573 non-null  int64
#  8   p_throws           130573 non-null  object
#  9   game_year          130573 non-null  int64
#  10  vx0                130573 non-null  float64
#  11  vy0                130573 non-null  float64
#  12  vz0                130573 non-null  float64
#  13  ax                 130573 non-null  float64
#  14  ay                 130573 non-null  float64
#  15  az                 130573 non-null  float64
#  16  effective_speed    130573 non-null  float64
#  17  release_spin_rate  130573 non-null  float64
#  18  release_extension  130573 non-null  float64
#  19  release_pos_y      130573 non-null  float64
#  20  pitch_name         130573 non-null  object
#  21  spin_axis          130573 non-null  float64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 21.9+ MB

# %%
all_2020_stats_df.reset_index(inplace=True)

# %%
all_2020_stats_df.drop('index', axis=1)
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0              SI  2020-09-27           88.9           2.98           5.29
# 1              SL  2020-09-27           74.8           2.10           5.73
# 2              SL  2020-09-27           75.3           2.01           5.74
# 3              SL  2020-09-27           75.8           2.38           5.20
# 4              SL  2020-09-27           75.0           2.70           5.15
# ...           ...         ...            ...            ...            ...
# 130568         FC  2020-07-25           84.5           2.99           4.99
# 130569         FC  2020-07-25           86.2           2.93           4.93
# 130570         FC  2020-07-25           84.0           3.08           4.95
# 130571         FC  2020-07-25           83.3           2.91           5.03
# 130572         SI  2020-07-25           88.3           2.50           5.62
#
#             player_name  pitcher p_throws  game_year        vx0  ...  \
# 0         Pérez, Oliver   424144        L       2020 -12.281452  ...
# 1         Pérez, Oliver   424144        L       2020  -2.377321  ...
# 2         Pérez, Oliver   424144        L       2020  -4.185552  ...
# 3         Pérez, Oliver   424144        L       2020  -6.816068  ...
# 4         Pérez, Oliver   424144        L       2020  -6.094674  ...
# ...                 ...      ...      ...        ...        ...  ...
# 130568  Yarbrough, Ryan   642232        L       2020  -6.460159  ...
# 130569  Yarbrough, Ryan   642232        L       2020  -7.496199  ...
# 130570  Yarbrough, Ryan   642232        L       2020  -4.905397  ...
# 130571  Yarbrough, Ryan   642232        L       2020  -8.406398  ...
# 130572  Yarbrough, Ryan   642232        L       2020  -8.490573  ...
#
#              vz0         ax         ay         az  effective_speed  \
# 0      -0.989660  20.383213  23.814852 -26.805910             88.9
# 1       0.610107  -4.717873  18.807153 -34.566989             74.8
# 2      -2.514557  -6.942147  18.406492 -34.069642             75.4
# 3       0.343225  -3.627673  18.464630 -32.767026             75.7
# 4       0.249817  -2.756490  18.526994 -33.136746             75.2
# ...          ...        ...        ...        ...              ...
# 130568 -1.305808  -0.528992  22.870380 -23.006810             85.8
# 130569 -1.008751   1.494699  25.298971 -21.592304             87.1
# 130570 -0.873244  -1.433915  22.925346 -22.045424             85.0
# 130571  1.309863   0.968236  22.529711 -22.522682             84.0
# 130572 -3.881882  13.916636  27.271728 -18.517555             88.9
#
#         release_spin_rate  release_extension  release_pos_y  pitch_name  \
# 0                  2130.0                6.2          54.34      Sinker
# 1                  2069.0                6.2          54.28      Slider
# 2                  2244.0                6.2          54.35      Slider
# 3                  2252.0                6.1          54.38      Slider
# 4                  2113.0                6.3          54.16      Slider
# ...                   ...                ...            ...         ...
# 130568             2098.0                7.0          53.53      Cutter
# 130569              745.0                6.8          53.67      Cutter
# 130570             2155.0                6.7          53.77      Cutter
# 130571             2169.0                6.7          53.82      Cutter
# 130572             1981.0                6.8          53.68      Sinker
#
#        spin_axis
# 0          125.0
# 1          309.0
# 2          312.0
# 3          299.0
# 4          293.0
# ...          ...
# 130568     180.0
# 130569     326.0
# 130570     126.0
# 130571     132.0
# 130572     122.0
#
# [130573 rows x 21 columns]

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2020_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2020_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2020_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'effective_speed': 'mean',
    'release_spin_rate': 'mean',
    'release_extension': 'mean',
    'release_pos_y': 'mean',
    'spin_axis': 'mean'
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2020_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2020_df = grouped_2020_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2020_df
# Out:
#        game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0     2020-07-23   453286             99         CH                   10
# 1     2020-07-23   453286             99         CU                    8
# 2     2020-07-23   453286             99         FC                    4
# 3     2020-07-23   453286             99         FF                   43
# 4     2020-07-23   453286             99         SL                   34
# ...          ...      ...            ...        ...                  ...
# 8339  2020-09-27   669160             55         SI                   30
# 8340  2020-09-27   669373             87         CH                   18
# 8341  2020-09-27   669373             87         FF                   52
# 8342  2020-09-27   669373             87         KC                    6
# 8343  2020-09-27   669373             87         SL                   11
#
#       release_speed  release_pos_x  release_pos_z        vx0         vy0  \
# 0         85.160000      -3.338000       5.277000   7.209278 -123.876290
# 1         76.962500      -3.251250       5.551250   4.855014 -111.999641
# 2         91.625000      -3.377500       5.157500  10.801746 -133.068760
# 3         95.039535      -3.243488       5.386279  10.403437 -138.046778
# 4         86.217647      -3.335294       5.360588   8.623404 -125.340521
# ...             ...            ...            ...        ...         ...
# 8339      97.936667      -2.335333       5.217333   9.414428 -142.344527
# 8340      81.561111       2.380000       6.597778  -6.735234 -118.553680
# 8341      94.292308       2.939615       6.372692  -9.042425 -136.920000
# 8342      76.133333       2.545000       6.528333  -4.323456 -110.721428
# 8343      85.572727       2.964545       6.275455  -7.388119 -124.457678
#
#            vz0         ax         ay         az  effective_speed  \
# 0    -2.673986 -12.466199  22.869016 -30.895543        85.700000
# 1    -0.266828   9.097057  20.609434 -38.588100        76.987500
# 2    -3.643193  -3.388934  25.558378 -23.253194        91.975000
# 3    -3.919061 -11.913946  28.725355 -14.844396        95.169767
# 4    -3.481782   1.530001  23.354777 -29.563498        86.338235
# ...        ...        ...        ...        ...              ...
# 8339 -3.645583 -23.055056  30.571561 -24.466004        98.406667
# 8340 -5.753956   8.251775  21.037793 -19.911349        81.500000
# 8341 -5.985816  13.348154  30.049353 -12.504125        93.844231
# 8342 -3.951126  -2.747840  21.625734 -41.674065        75.433333
# 8343 -4.018046  -0.379089  23.179273 -28.485636        85.572727
#
#       release_spin_rate  release_extension  release_pos_y   spin_axis
# 0           1312.500000           6.470000      54.029000  253.200000
# 1           2793.000000           6.337500      54.156250   58.500000
# 2           2585.750000           6.375000      54.135000  212.000000
# 3           2495.744186           6.313953      54.179302  222.232558
# 4           2432.705882           6.250000      54.256765  141.029412
# ...                 ...                ...            ...         ...
# 8339        2455.200000           6.466667      54.028000  237.933333
# 8340        1452.833333           6.144444      54.353333  144.222222
# 8341        2352.057692           6.130769      54.365577  142.019231
# 8342        2235.500000           6.016667      54.486667  340.666667
# 8343        2153.181818           6.154545      54.351818  155.818182
#
# [8344 rows x 19 columns]

# %%
grouped_2020_df['game_date'] = pd.to_datetime(grouped_2020_df['game_date'])
grouped_2020_df['season'] = grouped_2020_df['game_date'].dt.year
grouped_2020_df.head()
# Out:
#    game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0 2020-07-23   453286             99         CH                   10
# 1 2020-07-23   453286             99         CU                    8
# 2 2020-07-23   453286             99         FC                    4
# 3 2020-07-23   453286             99         FF                   43
# 4 2020-07-23   453286             99         SL                   34
#
#    release_speed  release_pos_x  release_pos_z        vx0         vy0  \
# 0      85.160000      -3.338000       5.277000   7.209278 -123.876290
# 1      76.962500      -3.251250       5.551250   4.855014 -111.999641
# 2      91.625000      -3.377500       5.157500  10.801746 -133.068760
# 3      95.039535      -3.243488       5.386279  10.403437 -138.046778
# 4      86.217647      -3.335294       5.360588   8.623404 -125.340521
#
#         vz0         ax         ay         az  effective_speed  \
# 0 -2.673986 -12.466199  22.869016 -30.895543        85.700000
# 1 -0.266828   9.097057  20.609434 -38.588100        76.987500
# 2 -3.643193  -3.388934  25.558378 -23.253194        91.975000
# 3 -3.919061 -11.913946  28.725355 -14.844396        95.169767
# 4 -3.481782   1.530001  23.354777 -29.563498        86.338235
#
#    release_spin_rate  release_extension  release_pos_y   spin_axis  season
# 0        1312.500000           6.470000      54.029000  253.200000    2020
# 1        2793.000000           6.337500      54.156250   58.500000    2020
# 2        2585.750000           6.375000      54.135000  212.000000    2020
# 3        2495.744186           6.313953      54.179302  222.232558    2020
# 4        2432.705882           6.250000      54.256765  141.029412    2020

# %%
# Step 1: Season Total Pitches
season_total_pitches = grouped_2020_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2020_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'effective_speed', 'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis']
for col in weighted_avg_columns:
    grouped_2020_df[f'{col}_product'] = grouped_2020_df[col] * grouped_2020_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2020_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2020_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2020_df = pd.merge(final_2020_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2020_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   424144    2020                   810         FF
# 1   424144    2020                   810         SI
# 2   424144    2020                   810         SL
# 3   425794    2020                  4559         CH
# 4   425794    2020                  4559         CU
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                                39                   39
# 1                               121                  121
# 2                               121                  121
# 3                                23                   23
# 4                               356                  356
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   89.520513                    2.129487
# 1                   89.959504                    2.629256
# 2                   76.057851                    2.562893
# 3                   81.847826                   -1.399130
# 4                   73.492697                   -1.181770
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.745897         -7.840932       -130.149708
# 1                    5.343471         -9.472237       -130.706890
# 2                    5.286198         -3.791649       -110.731949
# 3                    6.176522          3.939949       -119.145473
# 4                    6.308933          0.455951       -106.920727
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -4.256842        12.609126        25.924687       -16.737557
# 1         -2.087134        18.971616        25.758959       -24.803860
# 2          0.716512        -6.102009        19.328535       -33.279869
# 3         -4.111899       -11.555960        21.819291       -26.090190
# 4          0.374703        10.527821        21.408362       -41.397857
#
#    effective_speed_weighted_avg  release_spin_rate_weighted_avg  \
# 0                     89.666667                     2151.846154
# 1                     90.141322                     2102.239669
# 2                     76.026446                     2194.628099
# 3                     82.495652                     1683.478261
# 4                     73.251404                     2790.820225
#
#    release_extension_weighted_avg  release_pos_y_weighted_avg  \
# 0                        6.307692                   54.185897
# 1                        6.333884                   54.165537
# 2                        6.183471                   54.316033
# 3                        6.604348                   53.900435
# 4                        6.488483                   54.014410
#
#    spin_axis_weighted_avg
# 0              135.641026
# 1              129.876033
# 2              296.487603
# 3              226.086957
# 4               49.193820

# %%
final_2020_df.to_csv('final_2020_df.csv')
