# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2021_stats_df = pd.read_csv('all_2021_stats_df.csv', index_col=0)

# %%
all_2021_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x',
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2021_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SL  2021-04-22           77.1           2.64           5.04
# 1         SI  2021-04-22           89.2           2.40           5.35
# 2         SL  2021-04-22           75.8           2.80           5.12
# 3         SL  2021-04-22           75.7           2.49           5.24
# 4         SL  2021-04-22           77.5           2.51           5.35
#
#      player_name  pitcher  spin_dir p_throws  game_year  ...       vz0  \
# 0  Pérez, Oliver   424144       NaN        L       2021  ... -0.029166
# 1  Pérez, Oliver   424144       NaN        L       2021  ... -5.521146
# 2  Pérez, Oliver   424144       NaN        L       2021  ...  1.596070
# 3  Pérez, Oliver   424144       NaN        L       2021  ... -0.821613
# 4  Pérez, Oliver   424144       NaN        L       2021  ... -1.364256
#
#           ax         ay         az  effective_speed  release_spin_rate  \
# 0  -5.411125  18.340375 -32.951282             77.0             2025.0
# 1  20.596848  25.546150 -25.681085             89.0             1969.0
# 2  -6.340327  19.600470 -32.992715             75.2             2077.0
# 3  -6.826509  19.227540 -35.577637             75.6             2090.0
# 4  -5.827371  19.577191 -33.681240             77.2             2230.0
#
#    release_extension  release_pos_y  pitch_name  spin_axis
# 0                6.0          54.54      Slider      295.0
# 1                6.3          54.21      Sinker      128.0
# 2                5.9          54.63      Slider      278.0
# 3                6.1          54.42      Slider      293.0
# 4                5.9          54.62      Slider      298.0
#
# [5 rows x 22 columns]

# %%
all_2021_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349779 entries, 0 to 349778
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         349531 non-null  object
#  1   game_date          349779 non-null  object
#  2   release_speed      349531 non-null  float64
#  3   release_pos_x      349397 non-null  float64
#  4   release_pos_z      349397 non-null  float64
#  5   player_name        349779 non-null  object
#  6   pitcher            349779 non-null  int64
#  7   spin_dir           0 non-null       float64
#  8   p_throws           349779 non-null  object
#  9   game_year          349779 non-null  int64
#  10  vx0                349531 non-null  float64
#  11  vy0                349531 non-null  float64
#  12  vz0                349531 non-null  float64
#  13  ax                 349531 non-null  float64
#  14  ay                 349531 non-null  float64
#  15  az                 349531 non-null  float64
#  16  effective_speed    349531 non-null  float64
#  17  release_spin_rate  348211 non-null  float64
#  18  release_extension  349013 non-null  float64
#  19  release_pos_y      349397 non-null  float64
#  20  pitch_name         349531 non-null  object
#  21  spin_axis          348211 non-null  float64
# dtypes: float64(15), int64(2), object(5)
# memory usage: 61.4+ MB

# %%
all_2021_stats_df = all_2021_stats_df.drop(columns='spin_dir', axis=0)

# %%
all_2021_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349779 entries, 0 to 349778
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         349531 non-null  object
#  1   game_date          349779 non-null  object
#  2   release_speed      349531 non-null  float64
#  3   release_pos_x      349397 non-null  float64
#  4   release_pos_z      349397 non-null  float64
#  5   player_name        349779 non-null  object
#  6   pitcher            349779 non-null  int64
#  7   p_throws           349779 non-null  object
#  8   game_year          349779 non-null  int64
#  9   vx0                349531 non-null  float64
#  10  vy0                349531 non-null  float64
#  11  vz0                349531 non-null  float64
#  12  ax                 349531 non-null  float64
#  13  ay                 349531 non-null  float64
#  14  az                 349531 non-null  float64
#  15  effective_speed    349531 non-null  float64
#  16  release_spin_rate  348211 non-null  float64
#  17  release_extension  349013 non-null  float64
#  18  release_pos_y      349397 non-null  float64
#  19  pitch_name         349531 non-null  object
#  20  spin_axis          348211 non-null  float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 58.7+ MB

# %%
all_2021_stats_df = all_2021_stats_df.dropna(axis=0)

# %%
all_2021_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348132 entries, 0 to 348131
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              348132 non-null  int64
#  1   pitch_type         348132 non-null  object
#  2   game_date          348132 non-null  object
#  3   release_speed      348132 non-null  float64
#  4   release_pos_x      348132 non-null  float64
#  5   release_pos_z      348132 non-null  float64
#  6   player_name        348132 non-null  object
#  7   pitcher            348132 non-null  int64
#  8   p_throws           348132 non-null  object
#  9   game_year          348132 non-null  int64
#  10  vx0                348132 non-null  float64
#  11  vy0                348132 non-null  float64
#  12  vz0                348132 non-null  float64
#  13  ax                 348132 non-null  float64
#  14  ay                 348132 non-null  float64
#  15  az                 348132 non-null  float64
#  16  effective_speed    348132 non-null  float64
#  17  release_spin_rate  348132 non-null  float64
#  18  release_extension  348132 non-null  float64
#  19  release_pos_y      348132 non-null  float64
#  20  pitch_name         348132 non-null  object
#  21  spin_axis          348132 non-null  float64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 58.4+ MB

# %%
all_2021_stats_df.reset_index(inplace=True)

# %%
all_2021_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348132 entries, 0 to 348131
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              348132 non-null  int64
#  1   pitch_type         348132 non-null  object
#  2   game_date          348132 non-null  object
#  3   release_speed      348132 non-null  float64
#  4   release_pos_x      348132 non-null  float64
#  5   release_pos_z      348132 non-null  float64
#  6   player_name        348132 non-null  object
#  7   pitcher            348132 non-null  int64
#  8   p_throws           348132 non-null  object
#  9   game_year          348132 non-null  int64
#  10  vx0                348132 non-null  float64
#  11  vy0                348132 non-null  float64
#  12  vz0                348132 non-null  float64
#  13  ax                 348132 non-null  float64
#  14  ay                 348132 non-null  float64
#  15  az                 348132 non-null  float64
#  16  effective_speed    348132 non-null  float64
#  17  release_spin_rate  348132 non-null  float64
#  18  release_extension  348132 non-null  float64
#  19  release_pos_y      348132 non-null  float64
#  20  pitch_name         348132 non-null  object
#  21  spin_axis          348132 non-null  float64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 58.4+ MB

# %%
all_2021_stats_df.drop('index', axis=1)
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0              SL  2021-04-22           77.1           2.64           5.04
# 1              SI  2021-04-22           89.2           2.40           5.35
# 2              SL  2021-04-22           75.8           2.80           5.12
# 3              SL  2021-04-22           75.7           2.49           5.24
# 4              SL  2021-04-22           77.5           2.51           5.35
# ...           ...         ...            ...            ...            ...
# 348127         FC  2021-04-02           80.4           2.97           5.19
# 348128         FC  2021-04-02           78.0           2.93           5.33
# 348129         CH  2021-04-02           77.7           2.40           5.72
# 348130         CH  2021-04-02           78.3           2.41           5.66
# 348131         SI  2021-04-02           84.0           2.32           5.97
#
#             player_name  pitcher p_throws  game_year        vx0  ...  \
# 0         Pérez, Oliver   424144        L       2021  -4.994353  ...
# 1         Pérez, Oliver   424144        L       2021 -12.068774  ...
# 2         Pérez, Oliver   424144        L       2021  -4.343389  ...
# 3         Pérez, Oliver   424144        L       2021  -2.947061  ...
# 4         Pérez, Oliver   424144        L       2021  -4.293105  ...
# ...                 ...      ...      ...        ...        ...  ...
# 348127  Yarbrough, Ryan   642232        L       2021  -6.941866  ...
# 348128  Yarbrough, Ryan   642232        L       2021  -4.393366  ...
# 348129  Yarbrough, Ryan   642232        L       2021  -5.088565  ...
# 348130  Yarbrough, Ryan   642232        L       2021  -5.959473  ...
# 348131  Yarbrough, Ryan   642232        L       2021  -6.439867  ...
#
#              vz0         ax         ay         az  effective_speed  \
# 0      -0.029166  -5.411125  18.340375 -32.951282             77.0
# 1      -5.521146  20.596848  25.546150 -25.681085             89.0
# 2       1.596070  -6.340327  19.600470 -32.992715             75.2
# 3      -0.821613  -6.826509  19.227540 -35.577637             75.6
# 4      -1.364256  -5.827371  19.577191 -33.681240             77.2
# ...          ...        ...        ...        ...              ...
# 348127  2.538122  -2.407899  21.550603 -28.315896             80.3
# 348128  5.358616  -4.010691  20.324781 -31.365379             78.0
# 348129 -2.115300  15.016157  22.156832 -24.777378             77.7
# 348130 -3.262805  15.839047  22.678801 -28.383158             78.0
# 348131 -4.397571  11.105702  25.535242 -17.419112             83.8
#
#         release_spin_rate  release_extension  release_pos_y  pitch_name  \
# 0                  2025.0                6.0          54.54      Slider
# 1                  1969.0                6.3          54.21      Sinker
# 2                  2077.0                5.9          54.63      Slider
# 3                  2090.0                6.1          54.42      Slider
# 4                  2230.0                5.9          54.62      Slider
# ...                   ...                ...            ...         ...
# 348127             2260.0                6.3          54.23      Cutter
# 348128             2237.0                6.2          54.26      Cutter
# 348129             2040.0                6.5          54.01    Changeup
# 348130             2169.0                6.3          54.18    Changeup
# 348131             2025.0                6.3          54.19      Sinker
#
#        spin_axis
# 0          295.0
# 1          128.0
# 2          278.0
# 3          293.0
# 4          298.0
# ...          ...
# 348127     205.0
# 348128     260.0
# 348129     108.0
# 348130      98.0
# 348131     123.0
#
# [348132 rows x 21 columns]

# %%
all_2021_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348132 entries, 0 to 348131
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              348132 non-null  int64
#  1   pitch_type         348132 non-null  object
#  2   game_date          348132 non-null  object
#  3   release_speed      348132 non-null  float64
#  4   release_pos_x      348132 non-null  float64
#  5   release_pos_z      348132 non-null  float64
#  6   player_name        348132 non-null  object
#  7   pitcher            348132 non-null  int64
#  8   p_throws           348132 non-null  object
#  9   game_year          348132 non-null  int64
#  10  vx0                348132 non-null  float64
#  11  vy0                348132 non-null  float64
#  12  vz0                348132 non-null  float64
#  13  ax                 348132 non-null  float64
#  14  ay                 348132 non-null  float64
#  15  az                 348132 non-null  float64
#  16  effective_speed    348132 non-null  float64
#  17  release_spin_rate  348132 non-null  float64
#  18  release_extension  348132 non-null  float64
#  19  release_pos_y      348132 non-null  float64
#  20  pitch_name         348132 non-null  object
#  21  spin_axis          348132 non-null  float64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 58.4+ MB

# %%
all_2021_stats_df.head()
# Out:
#    index pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0      0         SL  2021-04-22           77.1           2.64           5.04
# 1      1         SI  2021-04-22           89.2           2.40           5.35
# 2      2         SL  2021-04-22           75.8           2.80           5.12
# 3      3         SL  2021-04-22           75.7           2.49           5.24
# 4      4         SL  2021-04-22           77.5           2.51           5.35
#
#      player_name  pitcher p_throws  game_year  ...       vz0         ax  \
# 0  Pérez, Oliver   424144        L       2021  ... -0.029166  -5.411125
# 1  Pérez, Oliver   424144        L       2021  ... -5.521146  20.596848
# 2  Pérez, Oliver   424144        L       2021  ...  1.596070  -6.340327
# 3  Pérez, Oliver   424144        L       2021  ... -0.821613  -6.826509
# 4  Pérez, Oliver   424144        L       2021  ... -1.364256  -5.827371
#
#           ay         az  effective_speed  release_spin_rate  \
# 0  18.340375 -32.951282             77.0             2025.0
# 1  25.546150 -25.681085             89.0             1969.0
# 2  19.600470 -32.992715             75.2             2077.0
# 3  19.227540 -35.577637             75.6             2090.0
# 4  19.577191 -33.681240             77.2             2230.0
#
#    release_extension  release_pos_y  pitch_name  spin_axis
# 0                6.0          54.54      Slider      295.0
# 1                6.3          54.21      Sinker      128.0
# 2                5.9          54.63      Slider      278.0
# 3                6.1          54.42      Slider      293.0
# 4                5.9          54.62      Slider      298.0
#
# [5 rows x 22 columns]

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2021_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2021_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2021_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'effective_speed': 'mean',
    'release_spin_rate': 'mean',
    'release_extension': 'mean',
    'release_pos_y': 'mean',
    'spin_axis': 'mean'
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2021_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2021_df = grouped_2021_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2021_df
# Out:
#         game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0      2021-04-01   425844             82         CH                   20
# 1      2021-04-01   425844             82         CU                   14
# 2      2021-04-01   425844             82         FF                   35
# 3      2021-04-01   425844             82         SL                   13
# 4      2021-04-01   433589             11         CH                    2
# ...           ...      ...            ...        ...                  ...
# 22180  2021-10-03   659275             31         SL                   11
# 22181  2021-10-03   664353             84         CH                   14
# 22182  2021-10-03   664353             84         CU                   11
# 22183  2021-10-03   664353             84         FF                   43
# 22184  2021-10-03   664353             84         ST                   16
#
#        release_speed  release_pos_x  release_pos_z       vx0         vy0  \
# 0          86.980000      -1.844500       6.240000  4.828009 -126.479509
# 1          71.978571      -1.740000       6.279286  1.723053 -104.718069
# 2          88.600000      -1.834857       6.276571  4.529760 -128.863649
# 3          81.515385      -1.974615       6.358462  3.742444 -118.652480
# 4          79.700000      -2.220000       5.565000  5.038482 -115.953282
# ...              ...            ...            ...       ...         ...
# 22180      87.600000      -0.872727       6.289091  5.106751 -127.452147
# 22181      84.757143      -1.475714       6.181429  4.976913 -123.203882
# 22182      77.890909      -1.678182       6.283636  1.810414 -113.389664
# 22183      92.160465      -1.292791       6.543023  4.869206 -133.945821
# 22184      79.643750      -2.010000       6.021875  3.728326 -115.903304
#
#             vz0         ax         ay         az  effective_speed  \
# 0     -6.668000 -12.306288  25.056190 -26.387963        86.795000
# 1      0.256374   7.187579  20.484950 -39.669285        71.178571
# 2     -6.167951  -1.719817  26.257371 -16.546970        88.460000
# 3     -3.717340   6.064068  22.818517 -33.496252        81.276923
# 4     -1.490509 -10.934707  22.394118 -21.609805        80.950000
# ...         ...        ...        ...        ...              ...
# 22180 -4.733551  -2.581949  25.030011 -22.184763        87.145455
# 22181 -6.023072 -14.631819  25.358722 -20.632279        84.235714
# 22182  0.001352   4.412230  22.529631 -41.808911        77.136364
# 22183 -6.887675  -8.436958  30.075145 -10.379912        91.137209
# 22184 -2.136187   9.593130  22.798795 -29.418710        78.950000
#
#        release_spin_rate  release_extension  release_pos_y   spin_axis
# 0            1674.200000           6.155000      54.353000  226.850000
# 1            2473.857143           6.042857      54.455714   48.142857
# 2            2250.457143           6.188571      54.318000  190.057143
# 3            2492.923077           6.130769      54.375385   88.384615
# 4            1716.500000           7.250000      53.265000  207.000000
# ...                  ...                ...            ...         ...
# 22180        2293.636364           5.918182      54.587273  208.181818
# 22181        2026.785714           6.085714      54.415714  233.357143
# 22182        2508.636364           5.909091      54.578182   32.363636
# 22183        2178.720930           5.827907      54.673256  203.186047
# 22184        2481.500000           5.918750      54.586250   61.437500
#
# [22185 rows x 19 columns]

# %%
grouped_2021_df['game_date'] = pd.to_datetime(grouped_2021_df['game_date'])
grouped_2021_df['season'] = grouped_2021_df['game_date'].dt.year
grouped_2021_df.head()
# Out:
#    game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0 2021-04-01   425844             82         CH                   20
# 1 2021-04-01   425844             82         CU                   14
# 2 2021-04-01   425844             82         FF                   35
# 3 2021-04-01   425844             82         SL                   13
# 4 2021-04-01   433589             11         CH                    2
#
#    release_speed  release_pos_x  release_pos_z       vx0         vy0  \
# 0      86.980000      -1.844500       6.240000  4.828009 -126.479509
# 1      71.978571      -1.740000       6.279286  1.723053 -104.718069
# 2      88.600000      -1.834857       6.276571  4.529760 -128.863649
# 3      81.515385      -1.974615       6.358462  3.742444 -118.652480
# 4      79.700000      -2.220000       5.565000  5.038482 -115.953282
#
#         vz0         ax         ay         az  effective_speed  \
# 0 -6.668000 -12.306288  25.056190 -26.387963        86.795000
# 1  0.256374   7.187579  20.484950 -39.669285        71.178571
# 2 -6.167951  -1.719817  26.257371 -16.546970        88.460000
# 3 -3.717340   6.064068  22.818517 -33.496252        81.276923
# 4 -1.490509 -10.934707  22.394118 -21.609805        80.950000
#
#    release_spin_rate  release_extension  release_pos_y   spin_axis  season
# 0        1674.200000           6.155000      54.353000  226.850000    2021
# 1        2473.857143           6.042857      54.455714   48.142857    2021
# 2        2250.457143           6.188571      54.318000  190.057143    2021
# 3        2492.923077           6.130769      54.375385   88.384615    2021
# 4        1716.500000           7.250000      53.265000  207.000000    2021

# %%
# Step 1: Season Total Pitches
season_total_pitches = grouped_2021_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2021_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'effective_speed', 'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis']
for col in weighted_avg_columns:
    grouped_2021_df[f'{col}_product'] = grouped_2021_df[col] * grouped_2021_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2021_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2021_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2021_df = pd.merge(final_2021_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2021_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   424144    2021                   168         FF
# 1   424144    2021                   168         SI
# 2   424144    2021                   168         SL
# 3   425794    2021                 16442         CH
# 4   425794    2021                 16442         CS
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                                12                   12
# 1                                26                   26
# 2                                18                   18
# 3                               195                  195
# 4                                13                   13
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   88.925000                    2.095833
# 1                   89.211538                    2.453462
# 2                   75.938889                    2.497222
# 3                   82.732821                   -1.332974
# 4                   65.423077                   -1.343846
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.750833         -8.655121       -129.162072
# 1                    5.387308         -8.304638       -129.649446
# 2                    5.275556         -4.443050       -110.550929
# 3                    6.221949          4.256656       -120.412930
# 4                    6.389231         -0.149149        -95.070420
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -4.748852        13.550496        26.530789       -16.935946
# 1         -2.918503        19.609363        26.613081       -24.455613
# 2         -0.091396        -5.435074        19.534750       -33.912365
# 3         -4.388219       -12.066556        22.227444       -25.271837
# 4          2.627888         7.397234        17.501637       -40.406583
#
#    effective_speed_weighted_avg  release_spin_rate_weighted_avg  \
# 0                     88.766667                     2045.333333
# 1                     89.146154                     2063.538462
# 2                     75.594444                     2111.055556
# 3                     83.235385                     1714.687179
# 4                     64.676923                     2539.384615
#
#    release_extension_weighted_avg  release_pos_y_weighted_avg  \
# 0                        6.266667                   54.236667
# 1                        6.273077                   54.227308
# 2                        5.983333                   54.515000
# 3                        6.495897                   54.000769
# 4                        6.200000                   54.313077
#
#    spin_axis_weighted_avg
# 0              132.583333
# 1              125.576923
# 2              298.833333
# 3              222.579487
# 4               39.076923

# %%
final_2021_df.to_csv('final_2021_df.csv')
