# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2019_stats_df = pd.read_csv('all_2019_stats_df.csv', index_col=0)

# %%
all_2019_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x', 'spin_dir', 
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2019_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2019-09-25           92.8           2.67           5.27
# 1         SL  2019-09-25           79.0           2.76           5.05
# 2         SI  2019-09-25           92.3           2.69           5.23
# 3         SI  2019-09-25           93.4           2.50           5.46
# 4         SI  2019-09-25           92.0           2.68           5.32
#
#      player_name  pitcher  spin_dir p_throws  game_year  ...       vz0  \
# 0  Pérez, Oliver   424144       NaN        L       2019  ... -2.706251
# 1  Pérez, Oliver   424144       NaN        L       2019  ... -0.179789
# 2  Pérez, Oliver   424144       NaN        L       2019  ... -2.749173
# 3  Pérez, Oliver   424144       NaN        L       2019  ... -4.025866
# 4  Pérez, Oliver   424144       NaN        L       2019  ... -4.099021
#
#           ax         ay         az  effective_speed  release_spin_rate  \
# 0  20.815682  26.534344 -26.052975             92.9             2386.0
# 1  -5.467883  18.886644 -33.229707             78.2             2382.0
# 2  20.450020  26.399585 -26.726142             91.9             2284.0
# 3  19.220514  27.441481 -21.331724             93.7             2269.0
# 4  18.767819  26.641947 -21.251070             92.3             2243.0
#
#    release_extension  release_pos_y  pitch_name  spin_axis
# 0                6.2          54.28      Sinker      107.0
# 1                5.5          55.00      Slider      277.0
# 2                5.9          54.63      Sinker      105.0
# 3                6.5          54.03      Sinker      121.0
# 4                6.4          54.08      Sinker      122.0
#
# [5 rows x 22 columns]

# %%
all_2019_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 408463 entries, 0 to 408462
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         401453 non-null  object
#  1   game_date          408463 non-null  object
#  2   release_speed      401479 non-null  float64
#  3   release_pos_x      401469 non-null  float64
#  4   release_pos_z      401469 non-null  float64
#  5   player_name        408463 non-null  object
#  6   pitcher            408463 non-null  int64
#  7   spin_dir           0 non-null       float64
#  8   p_throws           408463 non-null  object
#  9   game_year          408463 non-null  int64
#  10  vx0                401469 non-null  float64
#  11  vy0                401469 non-null  float64
#  12  vz0                401469 non-null  float64
#  13  ax                 401469 non-null  float64
#  14  ay                 401469 non-null  float64
#  15  az                 401469 non-null  float64
#  16  effective_speed    402898 non-null  float64
#  17  release_spin_rate  396502 non-null  float64
#  18  release_extension  401469 non-null  float64
#  19  release_pos_y      401469 non-null  float64
#  20  pitch_name         401453 non-null  object
#  21  spin_axis          401469 non-null  float64
# dtypes: float64(15), int64(2), object(5)
# memory usage: 71.7+ MB

# %%
all_2019_stats_df = all_2019_stats_df.drop(columns='spin_dir', axis=0)

# %%
all_2019_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 408463 entries, 0 to 408462
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         401453 non-null  object
#  1   game_date          408463 non-null  object
#  2   release_speed      401479 non-null  float64
#  3   release_pos_x      401469 non-null  float64
#  4   release_pos_z      401469 non-null  float64
#  5   player_name        408463 non-null  object
#  6   pitcher            408463 non-null  int64
#  7   p_throws           408463 non-null  object
#  8   game_year          408463 non-null  int64
#  9   vx0                401469 non-null  float64
#  10  vy0                401469 non-null  float64
#  11  vz0                401469 non-null  float64
#  12  ax                 401469 non-null  float64
#  13  ay                 401469 non-null  float64
#  14  az                 401469 non-null  float64
#  15  effective_speed    402898 non-null  float64
#  16  release_spin_rate  396502 non-null  float64
#  17  release_extension  401469 non-null  float64
#  18  release_pos_y      401469 non-null  float64
#  19  pitch_name         401453 non-null  object
#  20  spin_axis          401469 non-null  float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 68.6+ MB

# %%
all_2019_stats_df = all_2019_stats_df.dropna(axis=0)

# %%
all_2019_stats_df.reset_index(inplace=True)

# %%
all_2019_stats_df.drop('index', axis=1)
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0              SI  2019-09-25           92.8           2.67           5.27
# 1              SL  2019-09-25           79.0           2.76           5.05
# 2              SI  2019-09-25           92.3           2.69           5.23
# 3              SI  2019-09-25           93.4           2.50           5.46
# 4              SI  2019-09-25           92.0           2.68           5.32
# ...           ...         ...            ...            ...            ...
# 396436         SI  2019-03-26           88.3           2.79           5.64
# 396437         FC  2019-03-26           84.3           3.08           5.19
# 396438         FC  2019-03-26           83.3           3.07           5.21
# 396439         SI  2019-03-26           86.9           2.84           5.74
# 396440         SI  2019-03-26           86.5           2.74           5.70
#
#             player_name  pitcher p_throws  game_year        vx0  ...  \
# 0         Pérez, Oliver   424144        L       2019 -10.325351  ...
# 1         Pérez, Oliver   424144        L       2019  -5.511426  ...
# 2         Pérez, Oliver   424144        L       2019  -7.420359  ...
# 3         Pérez, Oliver   424144        L       2019 -11.566874  ...
# 4         Pérez, Oliver   424144        L       2019 -10.802773  ...
# ...                 ...      ...      ...        ...        ...  ...
# 396436  Yarbrough, Ryan   642232        L       2019  -7.996148  ...
# 396437  Yarbrough, Ryan   642232        L       2019  -7.170905  ...
# 396438  Yarbrough, Ryan   642232        L       2019  -6.172516  ...
# 396439  Yarbrough, Ryan   642232        L       2019  -7.509314  ...
# 396440  Yarbrough, Ryan   642232        L       2019  -4.331087  ...
#
#              vz0         ax         ay         az  effective_speed  \
# 0      -2.706251  20.815682  26.534344 -26.052975             92.9
# 1      -0.179789  -5.467883  18.886644 -33.229707             78.2
# 2      -2.749173  20.450020  26.399585 -26.726142             91.9
# 3      -4.025866  19.220514  27.441481 -21.331724             93.7
# 4      -4.099021  18.767819  26.641947 -21.251070             92.3
# ...          ...        ...        ...        ...              ...
# 396436 -2.633611  16.906768  28.249247 -21.586628             87.5
# 396437  2.954996  -1.771360  23.484370 -28.422812             83.4
# 396438  0.678418  -2.298028  22.493648 -28.647200             82.7
# 396439 -4.739281  13.766272  27.127831 -19.357119             85.8
# 396440 -3.128347  14.299762  27.619882 -24.031311             85.4
#
#         release_spin_rate  release_extension  release_pos_y  pitch_name  \
# 0                  2386.0                6.2          54.28      Sinker
# 1                  2382.0                5.5          55.00      Slider
# 2                  2284.0                5.9          54.63      Sinker
# 3                  2269.0                6.5          54.03      Sinker
# 4                  2243.0                6.4          54.08      Sinker
# ...                   ...                ...            ...         ...
# 396436             2042.0                6.1          54.44      Sinker
# 396437             2265.0                5.8          54.73      Cutter
# 396438             2357.0                5.8          54.70      Cutter
# 396439             2036.0                5.9          54.64      Sinker
# 396440             1941.0                5.8          54.69      Sinker
#
#        spin_axis
# 0          107.0
# 1          277.0
# 2          105.0
# 3          121.0
# 4          122.0
# ...          ...
# 396436     124.0
# 396437     214.0
# 396438     221.0
# 396439     135.0
# 396440     120.0
#
# [396441 rows x 21 columns]

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2019_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2019_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2019_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'effective_speed': 'mean',
    'release_spin_rate': 'mean',
    'release_extension': 'mean',
    'release_pos_y': 'mean',
    'spin_axis': 'mean'
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2019_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2019_df = grouped_2019_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2019_df
# Out:
#         game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0      2019-03-20   453178             19         CH                    1
# 1      2019-03-20   453178             19         FF                   13
# 2      2019-03-20   453178             19         KC                    4
# 3      2019-03-20   453178             19         SL                    1
# 4      2019-03-20   542881             84         CH                   24
# ...           ...      ...            ...        ...                  ...
# 25336  2019-09-29   669160             14         FC                    8
# 25337  2019-09-29   669160             14         SI                    6
# 25338  2019-09-29   669203             24         CU                    1
# 25339  2019-09-29   669203             24         FF                   19
# 25340  2019-09-29   669203             24         SL                    4
#
#        release_speed  release_pos_x  release_pos_z       vx0         vy0  \
# 0          87.400000      -2.770000       5.560000  6.301667 -127.036288
# 1          93.061538      -2.714615       5.355385  7.593764 -135.293943
# 2          79.200000      -2.655000       5.487500  5.685894 -115.126837
# 3          90.200000      -2.930000       5.340000  4.683909 -131.308115
# 4          79.837500       1.571667       6.183750 -4.721592 -116.063364
# ...              ...            ...            ...       ...         ...
# 25336      91.137500      -2.896250       5.676250  8.123294 -132.520180
# 25337      97.666667      -2.681667       5.831667  7.905768 -141.915268
# 25338      78.200000      -0.650000       6.240000 -2.246144 -113.919430
# 25339      95.526316      -0.590526       6.180526  1.484765 -139.276629
# 25340      86.925000      -0.647500       6.115000  1.233684 -126.726273
#
#             vz0         ax         ay         az  effective_speed  \
# 0     -3.434120 -14.165200  24.736687 -19.456550        86.300000
# 1     -4.818766 -10.943347  27.017142 -13.161089        93.123077
# 2     -0.767239   6.646469  21.869629 -42.475745        78.475000
# 3     -2.696309  -0.977545  26.005499 -21.983700        90.000000
# 4     -4.240269   9.170048  21.139655 -20.315252        79.187500
# ...         ...        ...        ...        ...              ...
# 25336 -3.743334   1.437378  25.039969 -25.692219        90.800000
# 25337 -6.501384 -18.176780  31.970114 -18.280694        97.500000
# 25338  2.924649   5.596426  16.094937 -33.638233        78.300000
# 25339 -6.966432  -1.815082  21.502068 -19.243005        96.884211
# 25340 -3.667419   4.268296  18.322145 -31.528880        87.175000
#
#        release_spin_rate  release_extension  release_pos_y   spin_axis
# 0            1935.000000           5.600000      54.930000  226.000000
# 1            2441.923077           6.192308      54.312308  207.230769
# 2            2715.250000           5.900000      54.612500   37.250000
# 3            2149.000000           6.000000      54.520000  180.000000
# 4            1990.208333           5.829167      54.670417  143.458333
# ...                  ...                ...            ...         ...
# 25336        2735.875000           5.875000      54.626250  155.750000
# 25337        2406.000000           6.250000      54.258333  232.500000
# 25338        2659.000000           5.800000      54.710000   81.000000
# 25339        2628.210526           6.278947      54.232632  186.473684
# 25340        2772.000000           5.725000      54.795000   94.250000
#
# [25341 rows x 19 columns]

# %%
grouped_2019_df['game_date'] = pd.to_datetime(grouped_2019_df['game_date'])
grouped_2019_df['season'] = grouped_2019_df['game_date'].dt.year

# Step 1: Season Total Pitches
season_total_pitches = grouped_2019_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2019_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'effective_speed', 'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis']
for col in weighted_avg_columns:
    grouped_2019_df[f'{col}_product'] = grouped_2019_df[col] * grouped_2019_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2019_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2019_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2019_df = pd.merge(final_2019_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2019_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   282332    2019                  7517         CH
# 1   282332    2019                  7517         FC
# 2   282332    2019                  7517         FF
# 3   282332    2019                  7517         SI
# 4   282332    2019                  7517         SL
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                               211                  211
# 1                               725                  725
# 2                                22                   22
# 3                               248                  248
# 4                               464                  464
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   82.674408                    2.393412
# 1                   88.337241                    2.273379
# 2                   88.763636                    2.331364
# 3                   89.148790                    2.275000
# 4                   79.214871                    2.367931
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.752796         -5.653338       -120.457872
# 1                    5.963945         -6.565380       -128.645948
# 2                    5.940909         -7.039296       -129.273508
# 3                    5.922339         -6.771127       -129.767979
# 4                    5.852177         -3.166741       -115.354064
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -3.604889         8.409502        21.193982       -25.188489
# 1         -3.040643         1.313497        23.551380       -21.894275
# 2         -3.184720         7.442200        24.019079       -21.347738
# 3         -4.523327        14.151617        25.587384       -23.327270
# 4         -2.095740        -7.488853        21.284780       -31.060781
#
#    effective_speed_weighted_avg  release_spin_rate_weighted_avg  \
# 0                     84.372512                     1884.739336
# 1                     89.473517                     2194.220690
# 2                     90.127273                     2097.954545
# 3                     90.411290                     2051.080645
# 4                     79.439655                     2208.381466
#
#    release_extension_weighted_avg  release_pos_y_weighted_avg  \
# 0                        7.114218                   53.380284
# 1                        6.684000                   53.815683
# 2                        6.840909                   53.662273
# 3                        6.913710                   53.587621
# 4                        6.386853                   54.113621
#
#    spin_axis_weighted_avg
# 0              131.938389
# 1              180.224828
# 2              150.000000
# 3              122.536290
# 4              261.045259

# %%
final_2019_df.to_csv('final_2019_df.csv')
