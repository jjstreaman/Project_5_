# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2018_stats_df = pd.read_csv('all_2018_stats_df.csv', index_col=0)

# %%
all_2018_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x', 'spin_dir', 
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2018_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2018-09-29           93.3           2.20           5.41
# 1         SI  2018-09-29           92.6           2.50           5.22
# 2         SL  2018-09-29           79.2           2.72           4.81
# 3         SI  2018-09-29           93.0           2.53           5.22
# 4         SL  2018-09-29           77.9           2.55           5.01
#
#      player_name  pitcher p_throws  game_year        vx0  ...       vz0  \
# 0  Pérez, Oliver   424144        L       2018  -8.330570  ... -3.537231
# 1  Pérez, Oliver   424144        L       2018 -10.494050  ... -0.530389
# 2  Pérez, Oliver   424144        L       2018  -5.409580  ...  1.272910
# 3  Pérez, Oliver   424144        L       2018  -8.334664  ... -1.445371
# 4  Pérez, Oliver   424144        L       2018  -5.795064  ...  2.538368
#
#           ax         ay         az  effective_speed  release_spin_rate  \
# 0  12.754514  28.834540 -16.456552             92.4             2177.0
# 1  20.104869  28.268887 -28.840385             92.3             1941.0
# 2  -5.716481  20.118242 -34.375437             77.8             2197.0
# 3  18.395080  28.551413 -26.370682             92.7             2095.0
# 4  -5.319335  19.644658 -34.813534             76.3             2186.0
#
#    release_extension  release_pos_y       pitch_name spin_axis
# 0                5.8          54.68  4-Seam Fastball     144.0
# 1                6.2          54.34           Sinker     101.0
# 2                5.3          55.22           Slider     284.0
# 3                6.1          54.38           Sinker     109.0
# 4                5.2          55.32           Slider     287.0
#
# [5 rows x 21 columns]

# %%
all_2018_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412232 entries, 0 to 412231
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         410541 non-null  object
#  1   game_date          412232 non-null  object
#  2   release_speed      410620 non-null  float64
#  3   release_pos_x      410601 non-null  float64
#  4   release_pos_z      410601 non-null  float64
#  5   player_name        412232 non-null  object
#  6   pitcher            412232 non-null  int64
#  7   p_throws           412232 non-null  object
#  8   game_year          412232 non-null  int64
#  9   vx0                410601 non-null  float64
#  10  vy0                410601 non-null  float64
#  11  vz0                410601 non-null  float64
#  12  ax                 410601 non-null  float64
#  13  ay                 410601 non-null  float64
#  14  az                 410601 non-null  float64
#  15  effective_speed    410827 non-null  float64
#  16  release_spin_rate  405223 non-null  float64
#  17  release_extension  410601 non-null  float64
#  18  release_pos_y      410601 non-null  float64
#  19  pitch_name         410541 non-null  object
#  20  spin_axis          410601 non-null  float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 69.2+ MB

# %%
all_2018_stats_df = all_2018_stats_df.dropna(axis=0)

# %%
all_2018_stats_df.reset_index(inplace=True)

# %%
all_2018_stats_df.drop('index', axis=1)
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0              FF  2018-09-29           93.3           2.20           5.41
# 1              SI  2018-09-29           92.6           2.50           5.22
# 2              SL  2018-09-29           79.2           2.72           4.81
# 3              SI  2018-09-29           93.0           2.53           5.22
# 4              SL  2018-09-29           77.9           2.55           5.01
# ...           ...         ...            ...            ...            ...
# 404916         CH  2018-03-31           81.4           2.79           5.52
# 404917         CH  2018-03-31           80.9           2.80           5.51
# 404918         FC  2018-03-31           86.4           2.97           5.41
# 404919         CH  2018-03-31           82.0           2.77           5.51
# 404920         SI  2018-03-31           88.5           2.70           5.76
#
#             player_name  pitcher p_throws  game_year        vx0  ...  \
# 0         Pérez, Oliver   424144        L       2018  -8.330570  ...
# 1         Pérez, Oliver   424144        L       2018 -10.494050  ...
# 2         Pérez, Oliver   424144        L       2018  -5.409580  ...
# 3         Pérez, Oliver   424144        L       2018  -8.334664  ...
# 4         Pérez, Oliver   424144        L       2018  -5.795064  ...
# ...                 ...      ...      ...        ...        ...  ...
# 404916  Yarbrough, Ryan   642232        L       2018 -10.837141  ...
# 404917  Yarbrough, Ryan   642232        L       2018  -7.979526  ...
# 404918  Yarbrough, Ryan   642232        L       2018 -10.306372  ...
# 404919  Yarbrough, Ryan   642232        L       2018  -8.287884  ...
# 404920  Yarbrough, Ryan   642232        L       2018  -8.404200  ...
#
#              vz0         ax         ay         az  effective_speed  \
# 0      -3.537231  12.754514  28.834540 -16.456552             92.4
# 1      -0.530389  20.104869  28.268887 -28.840385             92.3
# 2       1.272910  -5.716481  20.118242 -34.375437             77.8
# 3      -1.445371  18.395080  28.551413 -26.370682             92.7
# 4       2.538368  -5.319335  19.644658 -34.813534             76.3
# ...          ...        ...        ...        ...              ...
# 404916 -2.950963  16.324749  24.142674 -25.860317             80.4
# 404917 -3.728000  16.341647  24.487218 -27.021521             79.9
# 404918 -4.913631   1.708010  26.151788 -22.852170             85.1
# 404919 -0.893259  15.547702  24.170189 -26.184568             81.0
# 404920 -4.793352  19.636916  27.939173 -24.751264             87.9
#
#         release_spin_rate  release_extension  release_pos_y       pitch_name  \
# 0                  2177.0                5.8          54.68  4-Seam Fastball
# 1                  1941.0                6.2          54.34           Sinker
# 2                  2197.0                5.3          55.22           Slider
# 3                  2095.0                6.1          54.38           Sinker
# 4                  2186.0                5.2          55.32           Slider
# ...                   ...                ...            ...              ...
# 404916             1961.0                6.0          54.47         Changeup
# 404917             1990.0                6.0          54.53         Changeup
# 404918             2058.0                5.7          54.76           Cutter
# 404919             1741.0                5.9          54.58         Changeup
# 404920             1639.0                6.1          54.36           Sinker
#
#        spin_axis
# 0          144.0
# 1          101.0
# 2          284.0
# 3          109.0
# 4          287.0
# ...          ...
# 404916     113.0
# 404917     108.0
# 404918     183.0
# 404919     114.0
# 404920     110.0
#
# [404921 rows x 21 columns]

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2018_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2018_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2018_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'effective_speed': 'mean',
    'release_spin_rate': 'mean',
    'release_extension': 'mean',
    'release_pos_y': 'mean',
    'spin_axis': 'mean'
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2018_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2018_df = grouped_2018_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2018_df
# Out:
#         game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0      2018-03-29   407822              4         FC                    2
# 1      2018-03-29   407822              4         FF                    2
# 2      2018-03-29   430935             93         CH                   14
# 3      2018-03-29   430935             93         CU                   22
# 4      2018-03-29   430935             93         FC                   22
# ...           ...      ...            ...        ...                  ...
# 25153  2018-10-01   621111             92         SI                   21
# 25154  2018-10-01   621111             92         SL                   14
# 25155  2018-10-01   628317             10         FF                    5
# 25156  2018-10-01   628317             10         FS                    3
# 25157  2018-10-01   628317             10         SL                    2
#
#        release_speed  release_pos_x  release_pos_z       vx0         vy0  \
# 0          84.350000       2.750000       5.830000 -8.086980 -122.356397
# 1          92.150000       3.095000       5.575000 -8.970112 -133.723969
# 2          81.814286       2.497857       6.220714 -7.437962 -118.814369
# 3          77.872727       2.865455       5.988636 -5.920584 -113.152613
# 4          86.518182       2.756364       6.102727 -6.427376 -125.845940
# ...              ...            ...            ...       ...         ...
# 25153      96.690476      -1.320000       5.777619  4.500686 -140.642969
# 25154      84.264286      -1.311429       5.775000  2.445608 -122.647979
# 25155      92.660000      -1.964000       5.726000  6.428644 -134.840026
# 25156      86.233333      -1.973333       5.753333  7.041746 -125.260787
# 25157      84.900000      -1.915000       5.760000  5.499811 -123.551840
#
#             vz0         ax         ay         az  effective_speed  \
# 0     -3.333402  -2.799635  24.618739 -28.167485        82.500000
# 1     -4.006840  14.595338  29.262826 -17.170422        90.400000
# 2     -5.946986  11.560955  22.878002 -25.216116        81.707143
# 3     -0.650188  -3.149052  20.597412 -38.032918        76.922727
# 4     -4.856190  -0.884203  23.576812 -24.288409        86.650000
# ...         ...        ...        ...        ...              ...
# 25153 -6.327702 -15.829304  29.233166 -15.563721        96.638095
# 25154 -2.859529   8.251368  22.957213 -28.817950        83.578571
# 25155 -3.732740  -9.794189  25.485737 -14.734271        92.620000
# 25156 -7.264405 -12.652478  22.570192 -24.947276        85.633333
# 25157 -2.226909  -3.038583  21.643735 -23.428135        84.750000
#
#        release_spin_rate  release_extension  release_pos_y   spin_axis
# 0            2014.000000           5.250000      55.245000  233.500000
# 1            2053.000000           5.400000      55.115000  138.500000
# 2            1560.928571           6.350000      54.158571  119.785714
# 3            2240.045455           5.695455      54.815000  324.363636
# 4            1979.181818           6.200000      54.281818  199.000000
# ...                  ...                ...            ...         ...
# 25153        2340.095238           6.100000      54.398571  223.714286
# 25154        2797.071429           5.692857      54.798571  110.714286
# 25155        2363.600000           5.960000      54.526000  206.400000
# 25156        1524.333333           5.766667      54.743333  241.000000
# 25157        2547.000000           5.900000      54.580000  193.500000
#
# [25158 rows x 19 columns]

# %%
grouped_2018_df['game_date'] = pd.to_datetime(grouped_2018_df['game_date'])
grouped_2018_df['season'] = grouped_2018_df['game_date'].dt.year

# Step 1: Season Total Pitches
season_total_pitches = grouped_2018_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2018_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'effective_speed', 'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis']
for col in weighted_avg_columns:
    grouped_2018_df[f'{col}_product'] = grouped_2018_df[col] * grouped_2018_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2018_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2018_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2018_df = pd.merge(final_2018_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2018_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   112526    2018                 10189         CH
# 1   112526    2018                 10189         FC
# 2   112526    2018                 10189         FF
# 3   112526    2018                 10189         SI
# 4   112526    2018                 10189         SL
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                               247                  247
# 1                                62                   62
# 2                               365                  365
# 3                              1389                 1389
# 4                               154                  154
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   80.774494                   -1.500364
# 1                   85.533871                   -1.556774
# 2                   89.320000                   -1.232055
# 3                   86.858243                   -1.491706
# 4                   80.503247                   -1.566234
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.468300          4.206715       -117.349796
# 1                    5.545000          2.670307       -124.394402
# 2                    5.651151          3.858417       -129.755732
# 3                    5.441663          6.244949       -126.074042
# 4                    5.528831          4.221366       -116.965040
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -2.971755       -11.013014        22.168737       -26.209021
# 1         -3.081874        -0.999626        22.837186       -20.765071
# 2         -4.303520        -8.182075        26.732912       -16.754152
# 3         -2.451521       -15.729593        25.945832       -25.102962
# 4         -2.094540         2.365810        20.488754       -30.535709
#
#    effective_speed_weighted_avg  release_spin_rate_weighted_avg  \
# 0                     79.147368                     1657.178138
# 1                     83.993548                     2312.177419
# 2                     87.398356                     2279.843836
# 3                     84.861267                     2136.187185
# 4                     78.470779                     2387.844156
#
#    release_extension_weighted_avg  release_pos_y_weighted_avg  \
# 0                        5.237247                   55.260810
# 1                        5.111290                   55.386935
# 2                        5.131233                   55.367370
# 3                        5.157667                   55.342261
# 4                        4.784416                   55.716818
#
#    spin_axis_weighted_avg
# 0              241.085020
# 1              181.887097
# 2              206.246575
# 3              244.600432
# 4              112.915584

# %%
final_2018_df.to_csv('final_2018_df.csv')
