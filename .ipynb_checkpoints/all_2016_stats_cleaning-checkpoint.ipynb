# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2016_stats_df = pd.read_csv('all_2016_stats_df.csv', index_col=0)

# %%
all_2016_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x', 'spin_dir', 
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2016_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2016-09-27           91.5          -2.44           6.38
# 1         CU  2016-09-27           80.6          -2.11           6.73
# 2         FF  2016-09-27           91.5          -1.98           6.80
# 3         FF  2016-09-27           91.4          -2.10           6.78
# 4         CU  2016-09-27           79.3          -2.02           6.99
#
#    player_name  pitcher p_throws  game_year       vx0  ...       vz0      ax  \
# 0  Nathan, Joe   150274        R       2016  8.000700  ... -7.378708 -18.031
# 1  Nathan, Joe   150274        R       2016  6.025317  ... -5.264160   1.297
# 2  Nathan, Joe   150274        R       2016  9.976650  ... -4.307363 -10.986
# 3  Nathan, Joe   150274        R       2016  7.379398  ... -6.825156  -9.099
# 4  Nathan, Joe   150274        R       2016  6.382383  ... -1.735432   1.609
#
#        ay      az  effective_speed  release_spin_rate  release_extension  \
# 0  29.546 -23.736              NaN                NaN                NaN
# 1  21.976 -37.222              NaN                NaN                NaN
# 2  28.051 -14.246              NaN                NaN                NaN
# 3  27.598 -13.937              NaN                NaN                NaN
# 4  21.647 -39.715              NaN                NaN                NaN
#
#    release_pos_y       pitch_name spin_axis
# 0           54.5           Sinker       NaN
# 1           54.5        Curveball       NaN
# 2           54.5  4-Seam Fastball       NaN
# 3           54.5  4-Seam Fastball       NaN
# 4           54.5        Curveball       NaN
#
# [5 rows x 21 columns]

# %%
all_2016_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 428887 entries, 0 to 428886
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         428313 non-null  object
#  1   game_date          428887 non-null  object
#  2   release_speed      428835 non-null  float64
#  3   release_pos_x      428834 non-null  float64
#  4   release_pos_z      428834 non-null  float64
#  5   player_name        428887 non-null  object
#  6   pitcher            428887 non-null  int64
#  7   p_throws           428887 non-null  object
#  8   game_year          428887 non-null  int64
#  9   vx0                428834 non-null  float64
#  10  vy0                428834 non-null  float64
#  11  vz0                428834 non-null  float64
#  12  ax                 428835 non-null  float64
#  13  ay                 428835 non-null  float64
#  14  az                 428835 non-null  float64
#  15  effective_speed    423491 non-null  float64
#  16  release_spin_rate  395161 non-null  float64
#  17  release_extension  422056 non-null  float64
#  18  release_pos_y      428834 non-null  float64
#  19  pitch_name         428313 non-null  object
#  20  spin_axis          422057 non-null  float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 72.0+ MB

# %%
all_2016_stats_df = all_2016_stats_df.dropna(axis=0)

# %%
all_2016_stats_df.reset_index(inplace=True)

# %%
all_2016_stats_df.drop('index', axis=1)
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0              CU  2016-09-23           79.0          -1.81           6.89
# 1              SI  2016-09-23           91.6          -2.43           6.56
# 2              FF  2016-09-23           92.3          -1.96           6.64
# 3              FF  2016-09-23           92.1          -1.99           6.71
# 4              FF  2016-09-23           92.0          -1.82           6.75
# ...           ...         ...            ...            ...            ...
# 394647         SI  2016-04-07           92.5           1.71           5.76
# 394648         KC  2016-04-07           84.7           1.81           5.62
# 394649         SI  2016-04-07           91.5           1.69           5.82
# 394650         SI  2016-04-07           92.5           1.70           5.69
# 394651         SI  2016-04-07           92.0           1.81           5.82
#
#         player_name  pitcher p_throws  game_year       vx0  ...       vz0  \
# 0       Nathan, Joe   150274        R       2016  2.117915  ... -1.780961
# 1       Nathan, Joe   150274        R       2016  7.255357  ... -9.210113
# 2       Nathan, Joe   150274        R       2016  6.023301  ... -5.054441
# 3       Nathan, Joe   150274        R       2016  2.492124  ... -1.867261
# 4       Nathan, Joe   150274        R       2016  4.461015  ... -6.982414
# ...             ...      ...      ...        ...       ...  ...       ...
# 394647   Wood, Alex   622072        L       2016 -6.219613  ... -4.310726
# 394648   Wood, Alex   622072        L       2016 -9.595480  ... -1.008258
# 394649   Wood, Alex   622072        L       2016 -5.386997  ...  0.142351
# 394650   Wood, Alex   622072        L       2016 -5.634911  ... -5.505187
# 394651   Wood, Alex   622072        L       2016 -6.087716  ... -5.169572
#
#                ax         ay         az  effective_speed  release_spin_rate  \
# 0        5.954000  20.458000 -36.892000             77.3             2489.0
# 1      -16.542000  26.073000 -17.328000             91.1             2066.0
# 2       -6.265000  27.975000 -11.062000             92.7             2433.0
# 3       -4.401000  29.399000 -16.684000             92.0             2261.0
# 4       -4.267000  28.375000 -10.848000             91.0             2395.0
# ...           ...        ...        ...              ...                ...
# 394647  18.655000  28.975000 -22.036000             92.3             1871.0
# 394648  -2.593000  24.083000 -39.250000             84.1             2113.0
# 394649  15.479000  29.202000 -18.312000             91.0             2080.0
# 394650  15.570156  29.420771 -16.921047             91.2             1903.0
# 394651  17.060000  29.652000 -18.991000             92.1             2125.0
#
#         release_extension  release_pos_y       pitch_name spin_axis
# 0                     5.0           54.5        Curveball     343.0
# 1                     6.0           54.5           Sinker     241.0
# 2                     6.5           54.5  4-Seam Fastball     213.0
# 3                     6.2           54.5  4-Seam Fastball     218.0
# 4                     5.8           54.5  4-Seam Fastball     212.0
# ...                   ...            ...              ...       ...
# 394647                6.2           54.5           Sinker     128.0
# 394648                6.0           54.5    Knuckle Curve     228.0
# 394649                6.0           54.5           Sinker     138.0
# 394650                5.9           54.5           Sinker     134.0
# 394651                6.5           54.5           Sinker     124.0
#
# [394652 rows x 21 columns]

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2016_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2016_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2016_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'effective_speed': 'mean',
    'release_spin_rate': 'mean',
    'release_extension': 'mean',
    'release_pos_y': 'mean',
    'spin_axis': 'mean'
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2016_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2016_df = grouped_2016_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2016_df
# Out:
#         game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0      2016-04-03   112526             20         CH                    2
# 1      2016-04-03   112526             20         FF                    6
# 2      2016-04-03   112526             20         SI                   12
# 3      2016-04-03   425794             94         CH                    3
# 4      2016-04-03   425794             94         CU                   36
# ...           ...      ...            ...        ...                  ...
# 26437  2016-10-02   628317             50         SI                    1
# 26438  2016-10-02   628317             50         SL                    3
# 26439  2016-10-02   640455             82         CH                   17
# 26440  2016-10-02   640455             82         FF                   54
# 26441  2016-10-02   640455             82         SL                   11
#
#        release_speed  release_pos_x  release_pos_z        vx0         vy0  \
# 0          81.800000      -1.335000       5.780000   4.851660 -119.787286
# 1          90.566667      -1.003333       5.946667   2.685924 -132.855740
# 2          88.616667      -1.270833       5.784167   7.327535 -129.838566
# 3          84.133333      -1.760000       6.070000   4.282132 -123.264173
# 4          75.344444      -1.593056       6.185556   0.641844 -110.670350
# ...              ...            ...            ...        ...         ...
# 26437      86.700000      -2.070000       6.060000   5.183891 -126.856153
# 26438      81.600000      -1.926667       6.126667   5.641617 -119.399428
# 26439      85.452941       3.530588       5.768824 -10.285365 -125.034919
# 26440      92.968519       3.665185       5.576667 -12.487459 -136.026166
# 26441      80.700000       3.487273       5.692727  -9.003663 -118.138457
#
#             vz0         ax         ay         az  effective_speed  \
# 0     -2.685377 -12.956500  23.258500 -26.028000        80.100000
# 1     -5.540228  -9.709667  32.033833 -11.999333        87.883333
# 2     -3.304930 -16.743667  28.979000 -21.688833        86.500000
# 3     -2.101610 -10.890333  23.960333 -28.792000        84.266667
# 4      3.162772  14.000556  22.937000 -46.553556        74.361111
# ...         ...        ...        ...        ...              ...
# 26437 -2.875191 -14.049000  21.785000 -23.574000        86.800000
# 26438 -3.171174   3.587000  21.417667 -24.731333        81.233333
# 26439 -1.125048  11.198059  28.515588 -33.332294        84.552941
# 26440 -1.919446  18.609630  35.489833 -23.058944        92.188889
# 26441 -0.392826   0.446818  26.967364 -34.045909        79.463636
#
#        release_spin_rate  release_extension  release_pos_y   spin_axis
# 0            1674.500000           5.300000           54.5  259.500000
# 1            2278.166667           5.000000           54.5  214.166667
# 2            2084.916667           5.200000           54.5  244.250000
# 3            1863.000000           6.566667           54.5  254.000000
# 4            2729.027778           6.122222           54.5   46.222222
# ...                  ...                ...            ...         ...
# 26437        1977.000000           6.100000           54.5  217.000000
# 26438        2021.000000           6.033333           54.5  149.666667
# 26439        1509.647059           6.294118           54.5  103.470588
# 26440        1975.222222           6.574074           54.5  126.277778
# 26441        1972.636364           6.172727           54.5  252.636364
#
# [26442 rows x 19 columns]

# %%
grouped_2016_df['game_date'] = pd.to_datetime(grouped_2016_df['game_date'])
grouped_2016_df['season'] = grouped_2016_df['game_date'].dt.year

# Step 1: Season Total Pitches
season_total_pitches = grouped_2016_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2016_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'effective_speed', 'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis']
for col in weighted_avg_columns:
    grouped_2016_df[f'{col}_product'] = grouped_2016_df[col] * grouped_2016_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2016_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2016_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2016_df = pd.merge(final_2016_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2016_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   112526    2016                 10897         CH
# 1   112526    2016                 10897         FF
# 2   112526    2016                 10897         IN
# 3   112526    2016                 10897         SI
# 4   112526    2016                 10897         SL
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                               118                  118
# 1                               725                  725
# 2                                 8                    8
# 3                              1769                 1769
# 4                               146                  146
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   81.450000                   -1.319237
# 1                   90.352138                   -1.014028
# 2                   75.612500                   -1.372500
# 3                   87.628717                   -1.334890
# 4                   82.607534                   -1.413288
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.784322          4.464638       -119.338927
# 1                    5.945903          3.624549       -132.459837
# 2                    6.567500          3.370775       -110.710903
# 3                    5.739192          6.033524       -128.421766
# 4                    5.779658          4.418462       -120.997254
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -2.696046       -11.082424        23.763119       -25.096881
# 1         -4.111754        -7.385556        28.716928       -16.749423
# 2          0.906804        -5.831750        21.797125       -23.261375
# 3         -1.994050       -14.780649        27.321861       -24.526683
# 4         -1.380062         1.352301        22.844219       -27.480658
#
#    effective_speed_weighted_avg  release_spin_rate_weighted_avg  \
# 0                     79.765254                     1682.703390
# 1                     88.520966                     2263.673103
# 2                     72.862500                     1961.375000
# 3                     85.762408                     2100.307518
# 4                     80.657534                     2281.979452
#
#    release_extension_weighted_avg  release_pos_y_weighted_avg  \
# 0                        5.346610                        54.5
# 1                        5.311586                        54.5
# 2                        4.687500                        54.5
# 3                        5.304353                        54.5
# 4                        5.015753                        54.5
#
#    spin_axis_weighted_avg
# 0              234.288136
# 1              207.851034
# 2              216.500000
# 3              239.251555
# 4              169.993151

# %%
final_2016_df.to_csv('final_2016_df.csv')
