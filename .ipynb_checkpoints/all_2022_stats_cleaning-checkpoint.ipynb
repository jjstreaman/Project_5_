# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
from fuzzywuzzy import process
from sklearn.impute import SimpleImputer
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2022_stats_df = pd.read_csv('all_2022_stats_df.csv', index_col=0)

# %%
all_2022_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x',
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2022_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2022-04-24           87.8           2.74           5.20
# 1         SL  2022-04-24           75.8           2.12           5.60
# 2         SI  2022-04-24           87.3           2.45           5.41
# 3         SL  2022-04-24           76.9           2.35           5.38
# 4         SI  2022-04-24           87.1           2.49           5.42
#
#      player_name  pitcher  spin_dir p_throws  game_year  ...       vz0  \
# 0  Pérez, Oliver   424144       NaN        L       2022  ... -0.366773
# 1  Pérez, Oliver   424144       NaN        L       2022  ... -1.231512
# 2  Pérez, Oliver   424144       NaN        L       2022  ... -2.685717
# 3  Pérez, Oliver   424144       NaN        L       2022  ... -1.776512
# 4  Pérez, Oliver   424144       NaN        L       2022  ... -1.217999
#
#           ax         ay         az  effective_speed  release_spin_rate  \
# 0  19.671555  27.844065 -26.459826             87.2             2103.0
# 1  -3.993342  22.764887 -34.864845             74.9             2236.0
# 2  20.323170  27.956678 -25.185323             86.5             2147.0
# 3  -3.334614  23.340520 -33.618566             76.0             2177.0
# 4  18.127908  27.565163 -24.672644             86.7             2163.0
#
#    release_extension  release_pos_y  pitch_name  spin_axis
# 0                6.2          54.26      Sinker      122.0
# 1                6.1          54.44      Slider      309.0
# 2                6.2          54.33      Sinker      129.0
# 3                6.2          54.30      Slider      300.0
# 4                6.3          54.22      Sinker      133.0
#
# [5 rows x 22 columns]

# %%
all_2022_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 329955 entries, 0 to 329954
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         329843 non-null  object
#  1   game_date          329955 non-null  object
#  2   release_speed      329823 non-null  float64
#  3   release_pos_x      329823 non-null  float64
#  4   release_pos_z      329823 non-null  float64
#  5   player_name        329955 non-null  object
#  6   pitcher            329955 non-null  int64
#  7   spin_dir           0 non-null       float64
#  8   p_throws           329955 non-null  object
#  9   game_year          329955 non-null  int64
#  10  vx0                329823 non-null  float64
#  11  vy0                329823 non-null  float64
#  12  vz0                329823 non-null  float64
#  13  ax                 329823 non-null  float64
#  14  ay                 329823 non-null  float64
#  15  az                 329823 non-null  float64
#  16  effective_speed    329800 non-null  float64
#  17  release_spin_rate  329295 non-null  float64
#  18  release_extension  329621 non-null  float64
#  19  release_pos_y      329823 non-null  float64
#  20  pitch_name         329843 non-null  object
#  21  spin_axis          329275 non-null  float64
# dtypes: float64(15), int64(2), object(5)
# memory usage: 57.9+ MB

# %%
all_2022_stats_df.head(20)
# Out:
#    pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0          SI  2022-04-24           87.8           2.74           5.20
# 1          SL  2022-04-24           75.8           2.12           5.60
# 2          SI  2022-04-24           87.3           2.45           5.41
# 3          SL  2022-04-24           76.9           2.35           5.38
# 4          SI  2022-04-24           87.1           2.49           5.42
# 5          SI  2022-04-24           87.9           2.43           5.45
# 6          SL  2022-04-24           75.7           2.43           5.47
# 7          SI  2022-04-24           86.6           2.40           5.69
# 8          SI  2022-04-24           87.5           2.37           5.61
# 9          FF  2022-04-24           87.1           2.43           5.51
# 10         SL  2022-04-24           73.7           2.50           5.31
# 11         SL  2022-04-22           75.1           2.53           5.34
# 12         SI  2022-04-22           88.1           2.57           5.22
# 13         SL  2022-04-22           77.1           2.12           5.62
# 14         SI  2022-04-22           88.0           2.47           5.40
# 15         SI  2022-04-22           87.7           2.64           5.20
# 16         SI  2022-04-22           86.5           2.25           5.58
# 17         SI  2022-04-22           87.0           2.22           5.54
# 18         SI  2022-04-22           89.0           2.20           5.42
# 19         SI  2022-04-22           89.5           2.42           5.33
#
#       player_name  pitcher  spin_dir p_throws  game_year  ...       vz0  \
# 0   Pérez, Oliver   424144       NaN        L       2022  ... -0.366773
# 1   Pérez, Oliver   424144       NaN        L       2022  ... -1.231512
# 2   Pérez, Oliver   424144       NaN        L       2022  ... -2.685717
# 3   Pérez, Oliver   424144       NaN        L       2022  ... -1.776512
# 4   Pérez, Oliver   424144       NaN        L       2022  ... -1.217999
# 5   Pérez, Oliver   424144       NaN        L       2022  ... -5.404577
# 6   Pérez, Oliver   424144       NaN        L       2022  ... -0.902448
# 7   Pérez, Oliver   424144       NaN        L       2022  ... -2.513527
# 8   Pérez, Oliver   424144       NaN        L       2022  ... -2.590956
# 9   Pérez, Oliver   424144       NaN        L       2022  ... -1.526600
# 10  Pérez, Oliver   424144       NaN        L       2022  ...  0.984154
# 11  Pérez, Oliver   424144       NaN        L       2022  ...  1.347168
# 12  Pérez, Oliver   424144       NaN        L       2022  ... -1.795165
# 13  Pérez, Oliver   424144       NaN        L       2022  ... -5.734200
# 14  Pérez, Oliver   424144       NaN        L       2022  ... -2.221478
# 15  Pérez, Oliver   424144       NaN        L       2022  ...  0.659885
# 16  Pérez, Oliver   424144       NaN        L       2022  ... -4.164559
# 17  Pérez, Oliver   424144       NaN        L       2022  ... -4.888304
# 18  Pérez, Oliver   424144       NaN        L       2022  ... -3.862915
# 19  Pérez, Oliver   424144       NaN        L       2022  ...  0.084337
#
#            ax         ay         az  effective_speed  release_spin_rate  \
# 0   19.671555  27.844065 -26.459826             87.2             2103.0
# 1   -3.993342  22.764887 -34.864845             74.9             2236.0
# 2   20.323170  27.956678 -25.185323             86.5             2147.0
# 3   -3.334614  23.340520 -33.618566             76.0             2177.0
# 4   18.127908  27.565163 -24.672644             86.7             2163.0
# 5   19.001386  27.707740 -22.854347             87.3             2097.0
# 6   -5.562606  20.626994 -33.681408             75.1             2187.0
# 7   17.030288  26.681006 -22.805614             86.0             1968.0
# 8   17.383473  27.752172 -20.127481             86.8             2125.0
# 9   13.952521  27.712958 -20.170378             86.5             1955.0
# 10  -5.566271  21.403287 -32.499439             72.7             2024.0
# 11 -10.774771  21.888018 -34.020632             74.4             2365.0
# 12  18.519175  28.870417 -23.121450             87.1             2204.0
# 13  -4.018550  23.096511 -35.061543             76.3             2309.0
# 14  16.538593  29.566521 -23.290476             87.1             2180.0
# 15  19.643922  30.656067 -26.939884             86.6             2202.0
# 16  14.798654  28.159070 -20.862389             85.8             2117.0
# 17  15.406993  27.538783 -23.436754             86.4             2090.0
# 18  17.454396  29.298560 -23.633098             88.2             2144.0
# 19  17.457638  30.039347 -28.341088             88.8             2140.0
#
#     release_extension  release_pos_y       pitch_name  spin_axis
# 0                 6.2          54.26           Sinker      122.0
# 1                 6.1          54.44           Slider      309.0
# 2                 6.2          54.33           Sinker      129.0
# 3                 6.2          54.30           Slider      300.0
# 4                 6.3          54.22           Sinker      133.0
# 5                 6.2          54.28           Sinker      132.0
# 6                 6.0          54.52           Slider      295.0
# 7                 6.0          54.45           Sinker      136.0
# 8                 6.1          54.36           Sinker      130.0
# 9                 6.1          54.42  4-Seam Fastball      123.0
# 10                5.9          54.60           Slider      294.0
# 11                6.1          54.39           Slider      296.0
# 12                6.1          54.38           Sinker      125.0
# 13                6.1          54.37           Slider      301.0
# 14                6.1          54.44           Sinker      131.0
# 15                6.2          54.32           Sinker      128.0
# 16                6.2          54.30           Sinker      136.0
# 17                6.2          54.34           Sinker      136.0
# 18                6.2          54.29           Sinker      138.0
# 19                6.1          54.36           Sinker      128.0
#
# [20 rows x 22 columns]

# %%
nanrows = all_2022_stats_df[all_2022_stats_df.isnull().any(axis=1)]
nanrows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 329955 entries, 0 to 329954
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         329843 non-null  object
#  1   game_date          329955 non-null  object
#  2   release_speed      329823 non-null  float64
#  3   release_pos_x      329823 non-null  float64
#  4   release_pos_z      329823 non-null  float64
#  5   player_name        329955 non-null  object
#  6   pitcher            329955 non-null  int64
#  7   spin_dir           0 non-null       float64
#  8   p_throws           329955 non-null  object
#  9   game_year          329955 non-null  int64
#  10  vx0                329823 non-null  float64
#  11  vy0                329823 non-null  float64
#  12  vz0                329823 non-null  float64
#  13  ax                 329823 non-null  float64
#  14  ay                 329823 non-null  float64
#  15  az                 329823 non-null  float64
#  16  effective_speed    329800 non-null  float64
#  17  release_spin_rate  329295 non-null  float64
#  18  release_extension  329621 non-null  float64
#  19  release_pos_y      329823 non-null  float64
#  20  pitch_name         329843 non-null  object
#  21  spin_axis          329275 non-null  float64
# dtypes: float64(15), int64(2), object(5)
# memory usage: 57.9+ MB

# %%
all_2022_stats_df = all_2022_stats_df.drop(columns='spin_dir', axis=0)

# %%
all_2022_stats_df = all_2022_stats_df.dropna(axis=0)
all_2022_stats_df.reset_index(inplace=True)
all_2022_stats_df.drop('index', axis=1)
all_2022_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 329189 entries, 0 to 329954
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         329189 non-null  object
#  1   game_date          329189 non-null  object
#  2   release_speed      329189 non-null  float64
#  3   release_pos_x      329189 non-null  float64
#  4   release_pos_z      329189 non-null  float64
#  5   player_name        329189 non-null  object
#  6   pitcher            329189 non-null  int64
#  7   p_throws           329189 non-null  object
#  8   game_year          329189 non-null  int64
#  9   vx0                329189 non-null  float64
#  10  vy0                329189 non-null  float64
#  11  vz0                329189 non-null  float64
#  12  ax                 329189 non-null  float64
#  13  ay                 329189 non-null  float64
#  14  az                 329189 non-null  float64
#  15  effective_speed    329189 non-null  float64
#  16  release_spin_rate  329189 non-null  float64
#  17  release_extension  329189 non-null  float64
#  18  release_pos_y      329189 non-null  float64
#  19  pitch_name         329189 non-null  object
#  20  spin_axis          329189 non-null  float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 55.3+ MB

# %%
all_2022_stats_df.reset_index(inplace=True)

# %%
all_2022_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329189 entries, 0 to 329188
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              329189 non-null  int64
#  1   pitch_type         329189 non-null  object
#  2   game_date          329189 non-null  object
#  3   release_speed      329189 non-null  float64
#  4   release_pos_x      329189 non-null  float64
#  5   release_pos_z      329189 non-null  float64
#  6   player_name        329189 non-null  object
#  7   pitcher            329189 non-null  int64
#  8   p_throws           329189 non-null  object
#  9   game_year          329189 non-null  int64
#  10  vx0                329189 non-null  float64
#  11  vy0                329189 non-null  float64
#  12  vz0                329189 non-null  float64
#  13  ax                 329189 non-null  float64
#  14  ay                 329189 non-null  float64
#  15  az                 329189 non-null  float64
#  16  effective_speed    329189 non-null  float64
#  17  release_spin_rate  329189 non-null  float64
#  18  release_extension  329189 non-null  float64
#  19  release_pos_y      329189 non-null  float64
#  20  pitch_name         329189 non-null  object
#  21  spin_axis          329189 non-null  float64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 55.3+ MB

# %%
all_2022_stats_df.drop('index', axis=1)
all_2022_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329189 entries, 0 to 329188
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              329189 non-null  int64
#  1   pitch_type         329189 non-null  object
#  2   game_date          329189 non-null  object
#  3   release_speed      329189 non-null  float64
#  4   release_pos_x      329189 non-null  float64
#  5   release_pos_z      329189 non-null  float64
#  6   player_name        329189 non-null  object
#  7   pitcher            329189 non-null  int64
#  8   p_throws           329189 non-null  object
#  9   game_year          329189 non-null  int64
#  10  vx0                329189 non-null  float64
#  11  vy0                329189 non-null  float64
#  12  vz0                329189 non-null  float64
#  13  ax                 329189 non-null  float64
#  14  ay                 329189 non-null  float64
#  15  az                 329189 non-null  float64
#  16  effective_speed    329189 non-null  float64
#  17  release_spin_rate  329189 non-null  float64
#  18  release_extension  329189 non-null  float64
#  19  release_pos_y      329189 non-null  float64
#  20  pitch_name         329189 non-null  object
#  21  spin_axis          329189 non-null  float64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 55.3+ MB

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2022_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2022_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2022_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'effective_speed': 'mean',
    'release_spin_rate': 'mean',
    'release_extension': 'mean',
    'release_pos_y': 'mean',
    'spin_axis': 'mean'
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2022_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2022_df = grouped_2022_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2022_df
# Out:
#         game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0      2022-04-07   424144             17         FF                    1
# 1      2022-04-07   424144             17         SI                    8
# 2      2022-04-07   424144             17         SL                    8
# 3      2022-04-07   425794             81         CH                    9
# 4      2022-04-07   425794             81         CS                    2
# ...           ...      ...            ...        ...                  ...
# 20768  2022-10-05   669203             40         SI                    2
# 20769  2022-10-05   669203             40         SL                    2
# 20770  2022-10-05   670950             14         CH                    4
# 20771  2022-10-05   670950             14         CU                    2
# 20772  2022-10-05   670950             14         FF                    8
#
#        release_speed  release_pos_x  release_pos_z       vx0         vy0  \
# 0          89.900000        2.03000        5.74000 -9.318359 -130.529360
# 1          89.537500        2.59250        5.29250 -9.355620 -130.026518
# 2          77.200000        2.59750        5.26125 -5.923038 -112.245885
# 3          81.844444       -1.33000        6.27000  5.590011 -119.032142
# 4          69.150000       -1.23000        6.52000 -0.140925 -100.466403
# ...              ...            ...            ...       ...         ...
# 20768      97.100000       -0.39500        6.08000  6.480104 -141.148613
# 20769      88.600000       -0.43000        6.06000  3.863599 -129.031255
# 20770      83.000000       -2.71000        6.37000  7.266256 -120.633216
# 20771      86.700000       -2.83500        6.25000  8.448104 -125.980082
# 20772      93.112500       -2.47125        6.39250  7.610395 -135.275393
#
#             vz0         ax         ay         az  effective_speed  \
# 0     -2.925789  12.843168  30.543254 -13.743155        89.200000
# 1     -2.247511  19.655219  27.230138 -24.481376        89.300000
# 2     -0.436273  -3.795038  21.592220 -32.916980        76.750000
# 3     -4.480621 -13.473002  22.912257 -24.876686        82.077778
# 4      2.325922   9.639156  20.962770 -41.685075        68.050000
# ...         ...        ...        ...        ...              ...
# 20768 -6.428096 -12.527321  34.010686 -16.219134        96.900000
# 20769 -5.861031   7.469502  23.376470 -32.452655        89.150000
# 20770 -4.348898 -14.811971  22.487460 -30.169959        82.875000
# 20771 -6.124684  -1.480696  25.314384 -26.841340        86.650000
# 20772 -6.601083 -12.028607  28.983001 -11.287514        93.225000
#
#        release_spin_rate  release_extension  release_pos_y   spin_axis
# 0            2131.000000           6.300000      54.240000  137.000000
# 1            2193.125000           6.250000      54.248750  129.000000
# 2            2330.375000           6.162500      54.345000  295.000000
# 3            1718.777778           6.488889      54.013333  225.444444
# 4            2415.000000           6.150000      54.340000   41.500000
# ...                  ...                ...            ...         ...
# 20768        2594.000000           6.350000      54.145000  191.500000
# 20769        2804.500000           6.300000      54.215000  104.000000
# 20770        2721.000000           6.175000      54.327500  255.250000
# 20771        2176.000000           6.350000      54.195000  202.500000
# 20772        2270.625000           6.387500      54.102500  206.500000
#
# [20773 rows x 19 columns]

# %%
grouped_2022_df['game_date'] = pd.to_datetime(grouped_2022_df['game_date'])
grouped_2022_df['season'] = grouped_2022_df['game_date'].dt.year
grouped_2022_df.head()
# Out:
#    game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0 2022-04-07   424144             17         FF                    1
# 1 2022-04-07   424144             17         SI                    8
# 2 2022-04-07   424144             17         SL                    8
# 3 2022-04-07   425794             81         CH                    9
# 4 2022-04-07   425794             81         CS                    2
#
#    release_speed  release_pos_x  release_pos_z       vx0         vy0  \
# 0      89.900000         2.0300        5.74000 -9.318359 -130.529360
# 1      89.537500         2.5925        5.29250 -9.355620 -130.026518
# 2      77.200000         2.5975        5.26125 -5.923038 -112.245885
# 3      81.844444        -1.3300        6.27000  5.590011 -119.032142
# 4      69.150000        -1.2300        6.52000 -0.140925 -100.466403
#
#         vz0         ax         ay         az  effective_speed  \
# 0 -2.925789  12.843168  30.543254 -13.743155        89.200000
# 1 -2.247511  19.655219  27.230138 -24.481376        89.300000
# 2 -0.436273  -3.795038  21.592220 -32.916980        76.750000
# 3 -4.480621 -13.473002  22.912257 -24.876686        82.077778
# 4  2.325922   9.639156  20.962770 -41.685075        68.050000
#
#    release_spin_rate  release_extension  release_pos_y   spin_axis  season
# 0        2131.000000           6.300000      54.240000  137.000000    2022
# 1        2193.125000           6.250000      54.248750  129.000000    2022
# 2        2330.375000           6.162500      54.345000  295.000000    2022
# 3        1718.777778           6.488889      54.013333  225.444444    2022
# 4        2415.000000           6.150000      54.340000   41.500000    2022

# %%
# Step 1: Season Total Pitches
season_total_pitches = grouped_2022_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2022_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'effective_speed', 'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis']
for col in weighted_avg_columns:
    grouped_2022_df[f'{col}_product'] = grouped_2022_df[col] * grouped_2022_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2022_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2022_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2022_df = pd.merge(final_2022_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2022_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   424144    2022                   179         FF
# 1   424144    2022                   179         SI
# 2   424144    2022                   179         SL
# 3   425794    2022                 17258         CH
# 4   425794    2022                 17258         CS
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                                 3                    3
# 1                                43                   43
# 2                                27                   27
# 3                               189                  189
# 4                                33                   33
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   88.200000                    2.146667
# 1                   88.374419                    2.515349
# 2                   76.581481                    2.511111
# 3                   82.182540                   -1.314709
# 4                   67.660606                   -1.290909
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.686667         -7.529349       -128.207624
# 1                    5.368140         -9.023629       -128.309051
# 2                    5.314444         -4.872970       -111.373723
# 3                    6.223757          3.940298       -119.609919
# 4                    6.383030         -0.424688        -98.354011
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -2.140213        12.110056        28.717999       -16.369227
# 1         -2.396761        18.232210        28.215470       -24.538407
# 2         -0.449206        -5.493451        21.330117       -33.493125
# 3         -4.155740       -12.225405        22.425823       -25.149843
# 4          2.535486         8.542947        18.129059       -40.748865
#
#    effective_speed_weighted_avg  release_spin_rate_weighted_avg  \
# 0                     87.633333                     2058.666667
# 1                     87.772093                     2110.813953
# 2                     76.022222                     2255.851852
# 3                     82.499471                     1763.634921
# 4                     66.954545                     2567.090909
#
#    release_extension_weighted_avg  release_pos_y_weighted_avg  \
# 0                        6.200000                   54.323333
# 1                        6.174419                   54.325581
# 2                        6.062963                   54.434815
# 3                        6.424339                   54.075979
# 4                        6.133333                   54.366364
#
#    spin_axis_weighted_avg
# 0              133.000000
# 1              128.162791
# 2              297.370370
# 3              225.285714
# 4               39.818182

# %%
final_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   pitcher                           940 non-null    int64
#  1   season                            940 non-null    int32
#  2   season_total_pitches              940 non-null    int64
#  3   pitch_type                        940 non-null    object
#  4   season_total_count_by_pitch_type  940 non-null    int64
#  5   count_by_pitch_type               940 non-null    int64
#  6   release_speed_weighted_avg        940 non-null    float64
#  7   release_pos_x_weighted_avg        940 non-null    float64
#  8   release_pos_z_weighted_avg        940 non-null    float64
#  9   vx0_weighted_avg                  940 non-null    float64
#  10  vy0_weighted_avg                  940 non-null    float64
#  11  vz0_weighted_avg                  940 non-null    float64
#  12  ax_weighted_avg                   940 non-null    float64
#  13  ay_weighted_avg                   940 non-null    float64
#  14  az_weighted_avg                   940 non-null    float64
#  15  effective_speed_weighted_avg      940 non-null    float64
#  16  release_spin_rate_weighted_avg    940 non-null    float64
#  17  release_extension_weighted_avg    940 non-null    float64
#  18  release_pos_y_weighted_avg        940 non-null    float64
#  19  spin_axis_weighted_avg            940 non-null    float64
# dtypes: float64(14), int32(1), int64(4), object(1)
# memory usage: 143.3+ KB

# %%
final_2022_df.to_csv('final_2022_df.csv')
