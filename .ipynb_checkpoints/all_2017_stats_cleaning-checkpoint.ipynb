# %%
import pybaseball as pyb
from pybaseball import statcast, pitching_stats, playerid_lookup, statcast_pitcher, statcast_pitcher_pitch_arsenal, pitching_stats_bref, pitching_stats_range
import numpy as np
import math
import pandas as pd
import glob
import os
import re
import unicodedata
from datetime import datetime
from itertools import groupby
from operator import itemgetter
# Out:
# C:\Users\johns\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
all_2017_stats_df = pd.read_csv('all_2017_stats_df.csv', index_col=0)

# %%
all_2017_stats_df.drop(columns=['batter', 'events', 'description', 'zone',
                                'des', 'game_type', 'stand', 'home_team',
                                'away_team', 'type', 'hit_location', 'bb_type',
                                'balls', 'strikes', 'pfx_x', 'spin_dir', 
                                'pfx_z', 'plate_x', 'plate_z', 'on_3b',
                                'on_2b', 'on_1b', 'outs_when_up', 'inning',
                                'inning_topbot', 'hc_x', 'hc_y', 'fielder_2',
                                'umpire', 'sv_id', 'hit_distance_sc', 'sz_top',
                                 'sz_bot', 'launch_speed', 'launch_angle', 'game_pk',
                                'pitcher.1', 'fielder_2.1', 'fielder_3', 'fielder_4',
                                'fielder_5', 'fielder_6', 'fielder_7', 'fielder_8',
                                'fielder_9', 'estimated_ba_using_speedangle',
                                'estimated_woba_using_speedangle', 'babip_value',
                                'launch_speed_angle', 'woba_value', 'woba_denom', 'iso_value', 
                                'at_bat_number', 'pitch_number', 'home_score', 'away_score',
                                'bat_score', 'fld_score', 'post_home_score', 'post_bat_score',
                                'post_fld_score', 'post_away_score', 'if_fielding_alignment',
                                'of_fielding_alignment', 'delta_home_win_exp',
                                'delta_run_exp', 'spin_rate_deprecated', 'break_angle_deprecated',
                               'break_length_deprecated', 'tfs_deprecated', 'tfs_zulu_deprecated'], inplace=True)
all_2017_stats_df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2017-09-07           94.8          -2.68           6.27
# 1         CH  2017-09-07           85.1          -2.84           6.10
# 2         FF  2017-09-07           94.7          -2.77           6.31
# 3         CH  2017-09-07           85.1          -2.88           5.96
# 4         SI  2017-09-07           94.6          -2.73           6.25
#
#        player_name  pitcher p_throws  game_year       vx0  ...       vz0  \
# 0  Benoit, Joaquín   276542        R       2017  9.392586  ... -5.613659
# 1  Benoit, Joaquín   276542        R       2017  6.034954  ... -2.543159
# 2  Benoit, Joaquín   276542        R       2017  8.614072  ... -4.996384
# 3  Benoit, Joaquín   276542        R       2017  7.807054  ... -7.871553
# 4  Benoit, Joaquín   276542        R       2017  5.766298  ... -4.858858
#
#           ax         ay         az  effective_speed  release_spin_rate  \
# 0 -14.702656  31.677900 -13.541176             93.6             2192.0
# 1 -15.854333  21.528776 -25.575178             85.0             1340.0
# 2 -17.240459  30.795659 -12.763479             94.0             2136.0
# 3 -17.665318  23.292138 -23.765604             84.8             1571.0
# 4 -17.101673  30.527648 -16.579887             93.6             2149.0
#
#    release_extension  release_pos_y       pitch_name spin_axis
# 0                6.0          54.53  4-Seam Fastball     218.0
# 1                6.0          54.50         Changeup     251.0
# 2                6.1          54.40  4-Seam Fastball     222.0
# 3                6.2          54.30         Changeup     250.0
# 4                5.9          54.63           Sinker     230.0
#
# [5 rows x 21 columns]

# %%
all_2017_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 415901 entries, 0 to 415900
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   pitch_type         413977 non-null  object
#  1   game_date          415901 non-null  object
#  2   release_speed      414253 non-null  float64
#  3   release_pos_x      414239 non-null  float64
#  4   release_pos_z      414239 non-null  float64
#  5   player_name        415901 non-null  object
#  6   pitcher            415901 non-null  int64
#  7   p_throws           415901 non-null  object
#  8   game_year          415901 non-null  int64
#  9   vx0                414239 non-null  float64
#  10  vy0                414239 non-null  float64
#  11  vz0                414239 non-null  float64
#  12  ax                 414239 non-null  float64
#  13  ay                 414239 non-null  float64
#  14  az                 414239 non-null  float64
#  15  effective_speed    413304 non-null  float64
#  16  release_spin_rate  405874 non-null  float64
#  17  release_extension  414239 non-null  float64
#  18  release_pos_y      414239 non-null  float64
#  19  pitch_name         413977 non-null  object
#  20  spin_axis          414239 non-null  float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 69.8+ MB

# %%
all_2017_stats_df = all_2017_stats_df.dropna(axis=0)

# %%
all_2017_stats_df.reset_index(inplace=True)

# %%
all_2017_stats_df.drop('index', axis=1)
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0              FF  2017-09-07           94.8          -2.68           6.27
# 1              CH  2017-09-07           85.1          -2.84           6.10
# 2              FF  2017-09-07           94.7          -2.77           6.31
# 3              CH  2017-09-07           85.1          -2.88           5.96
# 4              SI  2017-09-07           94.6          -2.73           6.25
# ...           ...         ...            ...            ...            ...
# 405560         FF  2017-08-04           94.8          -1.18           6.08
# 405561         CH  2017-08-04           84.9          -1.30           6.01
# 405562         FF  2017-08-04           95.7          -1.36           6.19
# 405563         FF  2017-08-04           94.7          -1.45           6.13
# 405564         FF  2017-08-04           93.4          -1.29           6.24
#
#               player_name  pitcher p_throws  game_year       vx0  ...  \
# 0         Benoit, Joaquín   276542        R       2017  9.392586  ...
# 1         Benoit, Joaquín   276542        R       2017  6.034954  ...
# 2         Benoit, Joaquín   276542        R       2017  8.614072  ...
# 3         Benoit, Joaquín   276542        R       2017  7.807054  ...
# 4         Benoit, Joaquín   276542        R       2017  5.766298  ...
# ...                   ...      ...      ...        ...       ...  ...
# 405560  Woodruff, Brandon   605540        R       2017  7.155374  ...
# 405561  Woodruff, Brandon   605540        R       2017  2.862333  ...
# 405562  Woodruff, Brandon   605540        R       2017  6.004405  ...
# 405563  Woodruff, Brandon   605540        R       2017  4.356387  ...
# 405564  Woodruff, Brandon   605540        R       2017  3.568693  ...
#
#              vz0         ax         ay         az  effective_speed  \
# 0      -5.613659 -14.702656  31.677900 -13.541176             93.6
# 1      -2.543159 -15.854333  21.528776 -25.575178             85.0
# 2      -4.996384 -17.240459  30.795659 -12.763479             94.0
# 3      -7.871553 -17.665318  23.292138 -23.765604             84.8
# 4      -4.858858 -17.101673  30.527648 -16.579887             93.6
# ...          ...        ...        ...        ...              ...
# 405560 -3.221901 -11.943332  29.254469 -20.193995             95.4
# 405561 -4.458082 -16.599539  24.656263 -29.315716             85.4
# 405562 -4.077824 -16.298054  30.945885 -12.216903             95.0
# 405563 -4.894708 -14.615018  30.857577 -18.237897             94.7
# 405564 -6.475282 -15.903644  30.277817 -14.956756             92.8
#
#         release_spin_rate  release_extension  release_pos_y       pitch_name  \
# 0                  2192.0                6.0          54.53  4-Seam Fastball
# 1                  1340.0                6.0          54.50         Changeup
# 2                  2136.0                6.1          54.40  4-Seam Fastball
# 3                  1571.0                6.2          54.30         Changeup
# 4                  2149.0                5.9          54.63           Sinker
# ...                   ...                ...            ...              ...
# 405560             2049.0                6.6          53.87  4-Seam Fastball
# 405561             1720.0                6.6          53.87         Changeup
# 405562             2201.0                6.0          54.48  4-Seam Fastball
# 405563             2056.0                6.4          54.10  4-Seam Fastball
# 405564             2173.0                6.1          54.36  4-Seam Fastball
#
#        spin_axis
# 0          218.0
# 1          251.0
# 2          222.0
# 3          250.0
# 4          230.0
# ...          ...
# 405560     226.0
# 405561     267.0
# 405562     220.0
# 405563     230.0
# 405564     226.0
#
# [405565 rows x 21 columns]

# %%
# Group by 'game_date' and 'pitcher' to calculate the total pitches
total_pitches = all_2017_stats_df.groupby(['game_date', 'pitcher']).size().reset_index(name='total_pitches')

# Group by 'game_date', 'pitcher', and 'pitch_type' to calculate the sum total of each pitch_type
total_pitches_by_type = all_2017_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).size().reset_index(name='count_by_pitch_type')

# Calculate averages of the specified metrics for each pitch type, grouped by game_date and pitcher
avg_metrics = all_2017_stats_df.groupby(['game_date', 'pitcher', 'pitch_type']).agg({
    'release_speed': 'mean',
    'release_pos_x': 'mean',
    'release_pos_z': 'mean',
    'vx0': 'mean',
    'vy0': 'mean',
    'vz0': 'mean',
    'ax': 'mean',
    'ay': 'mean',
    'az': 'mean',
    'effective_speed': 'mean',
    'release_spin_rate': 'mean',
    'release_extension': 'mean',
    'release_pos_y': 'mean',
    'spin_axis': 'mean'
}).reset_index()

# Merging total pitches and total pitches by type back if needed
# This step depends on how you want to structure your final DataFrame. You can merge these summary DataFrames
# based on 'game_date' and 'pitcher' columns to get a comprehensive summary DataFrame.

# Example merge (you can adjust or expand based on what you exactly need):
grouped_2017_df = total_pitches.merge(total_pitches_by_type, on=['game_date', 'pitcher'], how='left')
grouped_2017_df = grouped_2017_df.merge(avg_metrics, on=['game_date', 'pitcher', 'pitch_type'], how='left')

# Note: This example assumes you want to merge all these statistics back together. You might adjust the merging
# strategy based on your analysis needs, including how you want to handle the multi-level grouping and aggregation.
grouped_2017_df
# Out:
#         game_date  pitcher  total_pitches pitch_type  count_by_pitch_type  \
# 0      2017-04-02   407822              7         FF                    4
# 1      2017-04-02   407822              7         FS                    3
# 2      2017-04-02   425844             87         CH                   17
# 3      2017-04-02   425844             87         CU                    9
# 4      2017-04-02   425844             87         FF                    7
# ...           ...      ...            ...        ...                  ...
# 25481  2017-10-01   656756             62         CH                    8
# 25482  2017-10-01   656756             62         CU                   13
# 25483  2017-10-01   656756             62         FF                   12
# 25484  2017-10-01   656756             62         SI                   18
# 25485  2017-10-01   656756             62         SL                   11
#
#        release_speed  release_pos_x  release_pos_z       vx0         vy0  \
# 0          93.825000       2.260000       5.990000 -6.607681 -135.921584
# 1          84.533333       2.340000       6.150000 -8.156373 -122.196138
# 2          87.247059      -1.681176       6.166471  6.550356 -126.579763
# 3          75.100000      -1.262222       6.281111  2.570011 -108.963546
# 4          90.942857      -1.285714       6.252857  6.058655 -131.799314
# ...              ...            ...            ...       ...         ...
# 25481      83.650000       1.041250       7.048750 -2.071883 -121.182151
# 25482      79.615385       1.096154       7.116154 -2.066860 -115.459674
# 25483      90.941667       1.167500       7.154167 -5.024515 -131.596227
# 25484      90.950000       1.073889       7.193333 -3.060953 -131.869867
# 25485      86.181818       1.298182       7.032727 -4.706669 -124.837699
#
#             vz0         ax         ay         az  effective_speed  \
# 0     -5.623689   3.196978  30.598219 -15.917123        92.150000
# 1     -7.859948   3.235173  25.261696 -26.173908        82.600000
# 2     -6.270184 -18.556959  24.337743 -23.479711        86.588235
# 3     -1.389566   1.443842  20.525397 -38.338699        73.388889
# 4     -7.466639  -7.565104  27.793235 -12.249997        90.214286
# ...         ...        ...        ...        ...              ...
# 25481 -8.576298   9.013582  23.992686 -13.077166        82.625000
# 25482 -4.423073  -0.065391  22.021875 -30.745808        77.653846
# 25483 -9.564605   7.275212  28.663895  -9.136039        89.466667
# 25484 -7.958547  14.020222  27.840228 -13.890111        89.972222
# 25485 -8.199382   1.256129  24.920829 -20.587717        84.754545
#
#        release_spin_rate  release_extension  release_pos_y   spin_axis
# 0            1976.750000           5.575000      54.920000  172.750000
# 1            1326.333333           5.466667      55.030000  138.666667
# 2            1932.000000           5.917647      54.594706  248.176471
# 3            2592.111111           5.311111      55.192222   14.333333
# 4            2422.142857           6.042857      54.464286  199.857143
# ...                  ...                ...            ...         ...
# 25481        1839.250000           5.875000      54.631250  152.000000
# 25482        2344.000000           5.107692      55.383077  217.846154
# 25483        2144.666667           5.733333      54.752500  162.500000
# 25484        2098.000000           5.866667      54.639444  139.111111
# 25485        2232.545455           5.572727      54.914545  180.272727
#
# [25486 rows x 19 columns]

# %%
grouped_2017_df['game_date'] = pd.to_datetime(grouped_2017_df['game_date'])
grouped_2017_df['season'] = grouped_2017_df['game_date'].dt.year

# Step 1: Season Total Pitches
season_total_pitches = grouped_2017_df.groupby(['pitcher', 'season'])['total_pitches'].sum().reset_index(name='season_total_pitches')

# Step 2: Season Total by Pitch Type
season_total_by_pitch_type = grouped_2017_df.groupby(['pitcher', 'season', 'pitch_type'])['count_by_pitch_type'].sum().reset_index(name='season_total_count_by_pitch_type')

# Weighted Averages Calculation Setup
weighted_avg_columns = ['release_speed', 'release_pos_x', 'release_pos_z', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'effective_speed', 'release_spin_rate', 'release_extension', 'release_pos_y', 'spin_axis']
for col in weighted_avg_columns:
    grouped_2017_df[f'{col}_product'] = grouped_2017_df[col] * grouped_2017_df['count_by_pitch_type']

weighted_avg_aggregations = {f'{col}_product': 'sum' for col in weighted_avg_columns}
weighted_avg_aggregations['count_by_pitch_type'] = 'sum'

# Aggregate for weighted averages
weighted_avg_df = grouped_2017_df.groupby(['pitcher', 'season', 'pitch_type']).agg(weighted_avg_aggregations).reset_index()

# Calculate weighted averages
for col in weighted_avg_columns:
    weighted_avg_df[f'{col}_weighted_avg'] = weighted_avg_df[f'{col}_product'] / weighted_avg_df['count_by_pitch_type']

# Cleanup
weighted_avg_df.drop(columns=[f'{col}_product' for col in weighted_avg_columns], inplace=True)

# Merge season totals and weighted averages
final_2017_df = pd.merge(season_total_pitches, season_total_by_pitch_type, on=['pitcher', 'season'])
final_2017_df = pd.merge(final_2017_df, weighted_avg_df, on=['pitcher', 'season', 'pitch_type'])

final_2017_df.head()
# Out:
#    pitcher  season  season_total_pitches pitch_type  \
# 0   112526    2017                  9440         CH
# 1   112526    2017                  9440         FC
# 2   112526    2017                  9440         FF
# 3   112526    2017                  9440         SI
# 4   112526    2017                  9440         SL
#
#    season_total_count_by_pitch_type  count_by_pitch_type  \
# 0                               222                  222
# 1                                 7                    7
# 2                               450                  450
# 3                              1435                 1435
# 4                               166                  166
#
#    release_speed_weighted_avg  release_pos_x_weighted_avg  \
# 0                   81.251351                   -1.536577
# 1                   86.614286                   -1.597143
# 2                   90.281778                   -1.186000
# 3                   87.062787                   -1.526676
# 4                   81.513253                   -1.619398
#
#    release_pos_z_weighted_avg  vx0_weighted_avg  vy0_weighted_avg  \
# 0                    5.527883          4.725224       -117.850169
# 1                    5.680000          4.901744       -125.504292
# 2                    5.773956          4.087600       -130.885083
# 3                    5.512509          6.434277       -126.194251
# 4                    5.546807          5.398850       -118.244001
#
#    vz0_weighted_avg  ax_weighted_avg  ay_weighted_avg  az_weighted_avg  \
# 0         -3.227057       -11.585814        22.078801       -24.595902
# 1         -4.632348        -1.278403        25.673230       -16.198153
# 2         -4.594772        -8.723897        27.398956       -14.663100
# 3         -2.747981       -15.602021        25.226547       -22.762351
# 4         -2.236791         1.103959        20.815275       -27.593265
#
#    effective_speed_weighted_avg  release_spin_rate_weighted_avg  \
# 0                     79.679279                     1677.563063
# 1                     84.685714                     2300.428571
# 2                     88.311333                     2240.960000
# 3                     85.219582                     2086.601394
# 4                     79.608434                     2334.500000
#
#    release_extension_weighted_avg  release_pos_y_weighted_avg  \
# 0                        5.342342                   55.158378
# 1                        5.285714                   55.227143
# 2                        5.238667                   55.261489
# 3                        5.267596                   55.232753
# 4                        4.955422                   55.539880
#
#    spin_axis_weighted_avg
# 0              241.554054
# 1              180.714286
# 2              207.386667
# 3              241.807666
# 4              150.277108

# %%
final_2017_df.to_csv('final_2017_df.csv')
